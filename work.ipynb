# %%
from dotenv import load_dotenv
import os
from datetime import datetime, timedelta, timezone
import requests
load_dotenv()
# Out:
# True

# %%
load_dotenv()
API_KEY = os.getenv("RAPID_API_KEY")
API_HOST = os.getenv("API_HOST")

# %%
HEADERS = {
    "x-rapidapi-key": API_KEY,
    "x-rapidapi-host": API_HOST
}

# %%
def fetch_flights(iata):
    """
    Correct AeroDataBox endpoint (relative time window)
    """
    url = f"https://{API_HOST}/flights/airports/iata/{iata}"

    params = {
        "offsetMinutes": "-120",     # start 2 hours ago
        "durationMinutes": "720",    # 12-hour window
        "direction": "Both",
        "withCancelled": "true",
        "withCodeshared": "true",
        "withCargo": "true",
        "withPrivate": "true",
        "withLeg": "true",
        "withLocation": "false"
    }

    r = requests.get(url, headers=HEADERS, params=params)
    r.raise_for_status()
    return r.json()

# %%
import pandas as pd

# %%
flights = fetch_flights("DEL")
arrivals = flights.get("arrivals", [])
departures = flights.get("departures", [])

# %%
flights.keys()
# Out:
# dict_keys(['departures', 'arrivals'])

# %%
print(len(flights["departures"]), len(flights["arrivals"]))
# Out:
# 276 326

# %%
flights["departures"][0].keys()
# Out:
# dict_keys(['departure', 'arrival', 'number', 'status', 'codeshareStatus', 'isCargo', 'aircraft', 'airline'])

# %%
flights["arrivals"][0].keys()
# Out:
# dict_keys(['departure', 'arrival', 'number', 'callSign', 'status', 'codeshareStatus', 'isCargo', 'aircraft', 'airline'])

# %%
pd.DataFrame(arrivals)
# Out:
#                                              departure  \
# 0    {'airport': {'icao': 'VARP', 'iata': 'RPR', 'n...
# 1    {'airport': {'icao': 'YMML', 'iata': 'MEL', 'n...
# 2    {'airport': {'icao': 'VIDN', 'iata': 'DED', 'n...
# 3    {'airport': {'icao': 'VOGA', 'iata': 'GOX', 'n...
# 4    {'airport': {'icao': 'VOGO', 'iata': 'GOI', 'n...
# ..                                                 ...
# 321  {'airport': {'icao': 'VCBI', 'iata': 'CMB', 'n...
# 322  {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'n...
# 323  {'airport': {'icao': 'YSSY', 'iata': 'SYD', 'n...
# 324  {'airport': {'icao': 'OTHH', 'iata': 'DOH', 'n...
# 325  {'airport': {'icao': 'LTFM', 'iata': 'IST', 'n...
#
#                                                arrival   number callSign  \
# 0    {'scheduledTime': {'utc': '2025-12-13 11:15Z',...  AI 2636  AIC2636
# 1    {'scheduledTime': {'utc': '2025-12-13 11:15Z',...    QF 69    QFA69
# 2    {'scheduledTime': {'utc': '2025-12-13 11:15Z',...  6E 6611  IGO6611
# 3    {'scheduledTime': {'utc': '2025-12-13 11:15Z',...   SG 212   SEJ212
# 4    {'scheduledTime': {'utc': '2025-12-13 11:15Z',...  6E 6193  IGO6193
# ..                                                 ...      ...      ...
# 321  {'scheduledTime': {'utc': '2025-12-13 22:40Z',...   UL 191      NaN
# 322  {'scheduledTime': {'utc': '2025-12-13 22:45Z',...   AF 214      NaN
# 323  {'scheduledTime': {'utc': '2025-12-13 22:45Z',...   AI 301   AIC301
# 324  {'scheduledTime': {'utc': '2025-12-13 23:00Z',...  AI 2284      NaN
# 325  {'scheduledTime': {'utc': '2025-12-13 23:10Z',...    6E 12      NaN
#
#        status codeshareStatus  isCargo  \
# 0     Unknown      IsOperator    False
# 1    Expected      IsOperator    False
# 2     Unknown      IsOperator    False
# 3     Unknown      IsOperator    False
# 4     Unknown      IsOperator    False
# ..        ...             ...      ...
# 321  Expected         Unknown    False
# 322  Expected      IsOperator    False
# 323  Expected      IsOperator    False
# 324  Expected      IsOperator    False
# 325  Expected         Unknown    False
#
#                                               aircraft  \
# 0      {'modeS': '8014DB', 'model': 'Airbus A320 NEO'}
# 1    {'reg': 'VH-EBO', 'modeS': '7C1472', 'model': ...
# 2      {'modeS': '8015A4', 'model': 'Airbus A320 NEO'}
# 3    {'reg': 'VT-SXA', 'modeS': '800DA3', 'model': ...
# 4    {'reg': 'TC-TJR', 'modeS': '4BD152', 'model': ...
# ..                                                 ...
# 321                           {'model': 'Airbus A320'}
# 322                        {'model': 'Boeing 777-200'}
# 323  {'reg': 'VT-NAC', 'modeS': '800742', 'model': ...
# 324                       {'model': 'Airbus A320 NEO'}
# 325                      {'model': 'Boeing 777-300ER'}
#
#                                                airline
# 0    {'name': 'Air India', 'iata': 'AI', 'icao': 'A...
# 1      {'name': 'Qantas', 'iata': 'QF', 'icao': 'QFA'}
# 2      {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}
# 3    {'name': 'SpiceJet', 'iata': 'SG', 'icao': 'SEJ'}
# 4      {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}
# ..                                                 ...
# 321  {'name': 'SriLankan', 'iata': 'UL', 'icao': 'A...
# 322  {'name': 'Air France', 'iata': 'AF', 'icao': '...
# 323  {'name': 'Air India', 'iata': 'AI', 'icao': 'A...
# 324  {'name': 'Air India', 'iata': 'AI', 'icao': 'A...
# 325    {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}
#
# [326 rows x 9 columns]

# %%
pd.DataFrame(departures)
# Out:
#                                              departure  \
# 0    {'scheduledTime': {'utc': '2025-12-13 11:15Z',...
# 1    {'scheduledTime': {'utc': '2025-12-13 11:15Z',...
# 2    {'scheduledTime': {'utc': '2025-12-13 11:15Z',...
# 3    {'scheduledTime': {'utc': '2025-12-13 11:20Z',...
# 4    {'scheduledTime': {'utc': '2025-12-13 11:25Z',...
# ..                                                 ...
# 271  {'scheduledTime': {'utc': '2025-12-13 23:00Z',...
# 272  {'scheduledTime': {'utc': '2025-12-13 23:00Z',...
# 273  {'scheduledTime': {'utc': '2025-12-13 23:00Z',...
# 274  {'scheduledTime': {'utc': '2025-12-13 23:10Z',...
# 275  {'scheduledTime': {'utc': '2025-12-13 23:10Z',...
#
#                                                arrival   number    status  \
# 0    {'airport': {'icao': 'VOHB', 'iata': 'HBX', 'n...  6E 6398   Unknown
# 1    {'airport': {'icao': 'VAPO', 'iata': 'PNQ', 'n...   SG 938   Unknown
# 2    {'airport': {'icao': 'VOBL', 'iata': 'BLR', 'n...   6E 781  Expected
# 3    {'airport': {'icao': 'VNKT', 'iata': 'KTM', 'n...   RA 218   Unknown
# 4    {'airport': {'icao': 'VEPT', 'iata': 'PAT', 'n...  AI 1746   Unknown
# ..                                                 ...      ...       ...
# 271  {'airport': {'icao': 'VOBL', 'iata': 'BLR', 'n...  AI 2653  Expected
# 272  {'airport': {'icao': 'VAAH', 'iata': 'AMD', 'n...  6E 2308  Expected
# 273  {'airport': {'icao': 'VNKT', 'iata': 'KTM', 'n...   AI 215  Expected
# 274  {'airport': {'icao': 'VAPO', 'iata': 'PNQ', 'n...  6E 2471  Expected
# 275     {'airport': {'name': 'Nagpur'}, 'quality': []}  6E 6820  Expected
#
#     codeshareStatus  isCargo  \
# 0           Unknown    False
# 1        IsOperator    False
# 2        IsOperator    False
# 3        IsOperator    False
# 4        IsOperator    False
# ..              ...      ...
# 271      IsOperator    False
# 272         Unknown    False
# 273         Unknown    False
# 274         Unknown    False
# 275         Unknown    False
#
#                                               aircraft  \
# 0                             {'model': 'Airbus A320'}
# 1    {'reg': 'VT-MXD', 'modeS': '800D13', 'model': ...
# 2    {'reg': 'VT-ICF', 'modeS': '80172C', 'model': ...
# 3    {'reg': '9N-ALY', 'modeS': '70AA75', 'model': ...
# 4      {'modeS': '8014F3', 'model': 'Airbus A320 NEO'}
# ..                                                 ...
# 271                       {'model': 'Airbus A320 NEO'}
# 272                       {'model': 'Airbus A320 NEO'}
# 273                           {'model': 'Airbus A320'}
# 274                           {'model': 'Airbus A320'}
# 275                       {'model': 'Airbus A320 NEO'}
#
#                                                airline callSign
# 0      {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
# 1    {'name': 'SpiceJet', 'iata': 'SG', 'icao': 'SEJ'}   SEJ938
# 2      {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
# 3       {'name': 'Nepal', 'iata': 'RA', 'icao': 'RNA'}   RNA218
# 4    {'name': 'Air India', 'iata': 'AI', 'icao': 'A...  AIC1746
# ..                                                 ...      ...
# 271  {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# 272    {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
# 273  {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# 274    {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
# 275    {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
#
# [276 rows x 9 columns]

# %%
def fetch_airport(iata):
    url = f"https://{API_HOST}/airports/iata/{iata}"
    querystring = {"withTime":"true","withRunways":"true"}

    r = requests.get(url, headers=HEADERS, params=querystring)
    r.raise_for_status()
    return r.json()

# %%
def fetch_flights(iata):
    """
    Correct AeroDataBox flights endpoint (fixed date range)
    """
    start = datetime.now(timezone.utc).replace(hour=0, minute=0, second=0, microsecond=0)
    end = start + timedelta(days=1)

    url = (
        f"https://aerodatabox.p.rapidapi.com/flights/airports/iata/{iata}/"
        f"{start.strftime('%Y-%m-%dT%H:%M')}/"
        f"{end.strftime('%Y-%m-%dT%H:%M')}"
    )

    querystring = {"withLeg":"true","direction":"Both","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"true"}

    r = requests.get(url, headers=HEADERS, params=querystring)
    r.raise_for_status()
    return r.json()

# %%
airport_data = fetch_airport("DEL")

print(airport_data)
# Out:
# {'icao': 'VIDP', 'iata': 'DEL', 'shortName': 'Indira Gandhi', 'fullName': 'New Delhi Indira Gandhi', 'municipalityName': 'New Delhi', 'location': {'lat': 28.5665, 'lon': 77.1031}, 'elevation': {'meter': 236.83, 'km': 0.24, 'mile': 0.15, 'nm': 0.13, 'feet': 777.0}, 'country': {'code': 'IN', 'name': 'India'}, 'continent': {'code': 'AS', 'name': 'Asia'}, 'timeZone': 'Asia/Kolkata', 'urls': {'webSite': 'http://www.newdelhiairport.in/', 'wikipedia': 'https://en.wikipedia.org/wiki/Indira_Gandhi_International_Airport', 'flightRadar': 'https://www.flightradar24.com/28.57,77.10/14', 'googleMaps': 'https://www.google.com/maps/@28.566499,77.103103,14z'}, 'runways': [{'name': '09', 'trueHdg': 91.5, 'length': {'meter': 2827.93, 'km': 2.83, 'mile': 1.76, 'nm': 1.53, 'feet': 9278.0}, 'width': {'meter': 45.11, 'km': 0.05, 'mile': 0.03, 'nm': 0.02, 'feet': 148.0}, 'isClosed': False, 'location': {'lat': 28.570492, 'lon': 77.08804}, 'surface': 'Asphalt', 'displacedThreshold': {'meter': 0.0, 'km': 0.0, 'mile': 0.0, 'nm': 0.0, 'feet': 0.0}, 'hasLighting': True}, {'name': '10', 'trueHdg': 104.7, 'length': {'meter': 3809.09, 'km': 3.81, 'mile': 2.37, 'nm': 2.06, 'feet': 12497.0}, 'width': {'meter': 45.11, 'km': 0.05, 'mile': 0.03, 'nm': 0.02, 'feet': 148.0}, 'isClosed': False, 'location': {'lat': 28.567171, 'lon': 77.08483}, 'surface': 'Asphalt', 'displacedThreshold': {'meter': 0.0, 'km': 0.0, 'mile': 0.0, 'nm': 0.0, 'feet': 0.0}, 'hasLighting': True}, {'name': '11', 'trueHdg': 103.9, 'length': {'meter': 4378.15, 'km': 4.38, 'mile': 2.72, 'nm': 2.36, 'feet': 14364.0}, 'width': {'meter': 60.05, 'km': 0.06, 'mile': 0.04, 'nm': 0.03, 'feet': 197.0}, 'isClosed': False, 'location': {'lat': 28.54719, 'lon': 77.06576}, 'surface': 'Asphalt', 'displacedThreshold': {'meter': 628.0, 'km': 0.63, 'mile': 0.39, 'nm': 0.34, 'feet': 2060.37}, 'hasLighting': True}, {'name': '27', 'trueHdg': 271.5, 'length': {'meter': 2827.93, 'km': 2.83, 'mile': 1.76, 'nm': 1.53, 'feet': 9278.0}, 'width': {'meter': 45.11, 'km': 0.05, 'mile': 0.03, 'nm': 0.02, 'feet': 148.0}, 'isClosed': False, 'location': {'lat': 28.569822, 'lon': 77.11696}, 'surface': 'Asphalt', 'displacedThreshold': {'meter': 152.0, 'km': 0.15, 'mile': 0.09, 'nm': 0.08, 'feet': 498.69}, 'hasLighting': True}, {'name': '28', 'trueHdg': 284.7, 'length': {'meter': 3809.09, 'km': 3.81, 'mile': 2.37, 'nm': 2.06, 'feet': 12497.0}, 'width': {'meter': 45.11, 'km': 0.05, 'mile': 0.03, 'nm': 0.02, 'feet': 148.0}, 'isClosed': False, 'location': {'lat': 28.5585, 'lon': 77.12253}, 'surface': 'Asphalt', 'displacedThreshold': {'meter': 0.0, 'km': 0.0, 'mile': 0.0, 'nm': 0.0, 'feet': 0.0}, 'hasLighting': True}, {'name': '29', 'trueHdg': 283.9, 'length': {'meter': 4378.15, 'km': 4.38, 'mile': 2.72, 'nm': 2.36, 'feet': 14364.0}, 'width': {'meter': 60.05, 'km': 0.06, 'mile': 0.04, 'nm': 0.03, 'feet': 197.0}, 'isClosed': False, 'location': {'lat': 28.537743, 'lon': 77.109215}, 'surface': 'Asphalt', 'displacedThreshold': {'meter': 1430.0, 'km': 1.43, 'mile': 0.89, 'nm': 0.77, 'feet': 4691.6}, 'hasLighting': True}], 'currentTime': {'time': {'utc': '2025-12-13 11:11Z', 'local': '2025-12-13 16:41+05:30'}, 'timeZoneId': 'Asia/Kolkata'}}

# %%
with open("airport_del.json", "w") as f:
    import json
    json.dump(airport_data, f, indent=4)

# %%
import pytz

# %%
global test_data

# %%
import requests
from datetime import datetime, timedelta
import pytz

def fetch_flights_for_date(iata: str, date_str: str, code_type: str = "iata"):
    """
    Fetch flights for a selected date using absolute time windows.
    Splits the day into two calls:
      - 00:00 → 12:00
      - 12:00 → 24:00

    Returns arrivals and departures separately.
    """

    API_HOST = "aerodatabox.p.rapidapi.com"
    BASE_URL = f"https://{API_HOST}/flights/airports/{code_type}/{iata}"

    PARAMS = {
        "withLeg": "true",
        "direction": "Both",
        "withCancelled": "true",
        "withCodeshared": "true",
        "withCargo": "true",
        "withPrivate": "true",
        "withLocation": "true",
    }

    airport_tz = pytz.timezone("Asia/Kolkata")

    start_day = airport_tz.localize(
        datetime.strptime(date_str, "%Y-%m-%d")
    )

    windows = [
        (start_day, start_day + timedelta(hours=12)),
        (start_day + timedelta(hours=12), start_day + timedelta(days=1)),
    ]

    all_departures = []
    all_arrivals = []

    for start, end in windows:
        start_ts = start.strftime("%Y-%m-%dT%H:%M")
        end_ts = end.strftime("%Y-%m-%dT%H:%M")

        url = f"{BASE_URL}/{start_ts}/{end_ts}"
        print(f"Calling API: {url}")

        response = requests.get(url, headers=HEADERS, params=PARAMS)
        response.raise_for_status()

        global test_data
        test_data = response.json()

        break

        # data = response.json()

        # departures = data.get("departures", [])
        # arrivals = data.get("arrivals", [])

        # all_departures.extend(departures)
        # all_arrivals.extend(arrivals)

        print(
            f"Fetched {len(departures)} departures, "
            f"{len(arrivals)} arrivals"
        )

    return {
        "iata": iata,
        "date": date_str,
        "departureCount": len(all_departures),
        "arrivalCount": len(all_arrivals),
        "departures": all_departures,
        "arrivals": all_arrivals,
    }

# %%
airport_flights = fetch_flights_for_date("DEL", "2025-12-13")
# Out:
# Calling API: https://aerodatabox.p.rapidapi.com/flights/airports/iata/DEL/2025-12-13T00:00/2025-12-13T12:00

# %%
test_data
# Out:
# {'departures': [{'departure': {'scheduledTime': {'utc': '2025-12-12 18:35Z',
#      'local': '2025-12-13 00:05+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VABB',
#      'iata': 'BOM',
#      'name': 'Mumbai',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-12 20:55Z',
#      'local': '2025-12-13 02:25+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'AI 2451',
#    'callSign': 'AIC2451',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '801672', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 18:35Z',
#      'local': '2025-12-13 00:05+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VVTS',
#      'iata': 'SGN',
#      'name': 'Ho Chi Minh City',
#      'timeZone': 'Asia/Ho_Chi_Minh'},
#     'scheduledTime': {'utc': '2025-12-12 23:20Z',
#      'local': '2025-12-13 06:20+07:00'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'VJ 896',
#    'callSign': 'VJC896',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VN-A812',
#     'modeS': '8881C7',
#     'model': 'Airbus A330-300'},
#    'airline': {'name': 'VietJetAir', 'iata': 'VJ', 'icao': 'VJC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 18:45Z',
#      'local': '2025-12-13 00:15+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'RKSI',
#      'iata': 'ICN',
#      'name': 'Seoul',
#      'timeZone': 'Asia/Seoul'},
#     'scheduledTime': {'utc': '2025-12-13 01:30Z',
#      'local': '2025-12-13 10:30+09:00'},
#     'revisedTime': {'utc': '2025-12-13 01:23Z',
#      'local': '2025-12-13 10:23+09:00'},
#     'runwayTime': {'utc': '2025-12-13 01:23Z',
#      'local': '2025-12-13 10:23+09:00'},
#     'terminal': '1',
#     'gate': '39',
#     'baggageBelt': '21',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 312',
#    'callSign': 'AIC312',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-ANX', 'modeS': '80073E', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 18:45Z',
#      'local': '2025-12-13 00:15+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VHHH',
#      'iata': 'HKG',
#      'name': 'Hong Kong',
#      'timeZone': 'Asia/Shanghai'},
#     'scheduledTime': {'utc': '2025-12-12 23:55Z',
#      'local': '2025-12-13 07:55+08:00'},
#     'revisedTime': {'utc': '2025-12-12 23:33Z',
#      'local': '2025-12-13 07:33+08:00'},
#     'terminal': '1',
#     'gate': 'N10',
#     'baggageBelt': '14',
#     'quality': ['Basic', 'Live']},
#    'number': '6E 1707',
#    'callSign': 'IGO1707',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '801536', 'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 18:45Z',
#      'local': '2025-12-13 00:15+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VOBL',
#      'iata': 'BLR',
#      'name': 'Bangalore',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-12 21:40Z',
#      'local': '2025-12-13 03:10+05:30'},
#     'revisedTime': {'utc': '2025-12-12 22:06Z',
#      'local': '2025-12-13 03:36+05:30'},
#     'terminal': '2',
#     'baggageBelt': '8A',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 2757',
#    'callSign': 'AIC2757',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-TNU',
#     'modeS': '8013A3',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 18:50Z',
#      'local': '2025-12-13 00:20+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VTBS',
#      'iata': 'BKK',
#      'name': 'Bangkok',
#      'timeZone': 'Asia/Bangkok'},
#     'scheduledTime': {'utc': '2025-12-12 23:05Z',
#      'local': '2025-12-13 06:05+07:00'},
#     'revisedTime': {'utc': '2025-12-12 23:00Z',
#      'local': '2025-12-13 06:00+07:00'},
#     'gate': 'D2',
#     'quality': ['Basic', 'Live']},
#    'number': 'TG 316',
#    'callSign': 'THA316',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HS-TKL', 'modeS': '88516C', 'model': 'Boeing 777'},
#    'airline': {'name': 'Thai  International', 'iata': 'TG', 'icao': 'THA'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 18:55Z',
#      'local': '2025-12-13 00:25+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'CYUL',
#      'iata': 'YUL',
#      'name': 'Montreal',
#      'timeZone': 'America/Toronto'},
#     'scheduledTime': {'utc': '2025-12-13 11:10Z',
#      'local': '2025-12-13 06:10-05:00'},
#     'revisedTime': {'utc': '2025-12-13 11:14Z',
#      'local': '2025-12-13 06:14-05:00'},
#     'gate': '66',
#     'quality': ['Basic', 'Live']},
#    'number': 'AC 51',
#    'callSign': 'ACA51',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'C-FVLZ', 'modeS': 'C038AC', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Air Canada', 'iata': 'AC', 'icao': 'ACA'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 19:00Z',
#      'local': '2025-12-13 00:30+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Mumbai'}, 'quality': []},
#    'number': '6E 6787',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 19:25Z',
#      'local': '2025-12-13 00:55+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'YSSY',
#      'iata': 'SYD',
#      'name': 'Sydney',
#      'timeZone': 'Australia/Sydney'},
#     'scheduledTime': {'utc': '2025-12-13 08:15Z',
#      'local': '2025-12-13 19:15+11:00'},
#     'revisedTime': {'utc': '2025-12-13 07:49Z',
#      'local': '2025-12-13 18:49+11:00'},
#     'runwayTime': {'utc': '2025-12-13 07:45Z',
#      'local': '2025-12-13 18:45+11:00'},
#     'terminal': '1',
#     'runway': '34L',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 302',
#    'callSign': 'AIC302',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-NAC', 'modeS': '800742', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 19:55Z',
#      'local': '2025-12-13 01:25+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'YMML',
#      'iata': 'MEL',
#      'name': 'Melbourne',
#      'timeZone': 'Australia/Melbourne'},
#     'scheduledTime': {'utc': '2025-12-13 07:55Z',
#      'local': '2025-12-13 18:55+11:00'},
#     'revisedTime': {'utc': '2025-12-13 08:21Z',
#      'local': '2025-12-13 19:21+11:00'},
#     'runwayTime': {'utc': '2025-12-13 08:09Z',
#      'local': '2025-12-13 19:09+11:00'},
#     'terminal': '2',
#     'gate': '9',
#     'runway': '27',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 308',
#    'callSign': 'AIC308',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-ANA', 'modeS': '8005EB', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:00Z',
#      'local': '2025-12-13 01:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VHHH',
#      'iata': 'HKG',
#      'name': 'Hong Kong',
#      'timeZone': 'Asia/Shanghai'},
#     'scheduledTime': {'utc': '2025-12-13 01:25Z',
#      'local': '2025-12-13 09:25+08:00'},
#     'revisedTime': {'utc': '2025-12-13 02:23Z',
#      'local': '2025-12-13 10:23+08:00'},
#     'terminal': '1',
#     'gate': 'S33',
#     'baggageBelt': '17',
#     'quality': ['Basic', 'Live']},
#    'number': 'CX 694',
#    'callSign': 'CPA694',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'B-LQH', 'modeS': '789276', 'model': 'Airbus A350-900'},
#    'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:00Z',
#      'local': '2025-12-13 01:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2025-12-13 05:15Z',
#      'local': '2025-12-13 06:15+01:00'},
#     'revisedTime': {'utc': '2025-12-13 05:06Z',
#      'local': '2025-12-13 06:06+01:00'},
#     'terminal': '2E',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 225',
#    'callSign': 'AFR225',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-HRBB', 'modeS': '39C421', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:05Z',
#      'local': '2025-12-13 01:35+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2025-12-13 05:18Z',
#      'local': '2025-12-13 06:18+01:00'},
#     'revisedTime': {'utc': '2025-12-13 05:31Z',
#      'local': '2025-12-13 06:31+01:00'},
#     'runwayTime': {'utc': '2025-12-13 05:18Z',
#      'local': '2025-12-13 06:18+01:00'},
#     'runway': '16',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 187',
#    'callSign': 'AIC187',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-ALR', 'modeS': '8004E0', 'model': 'Boeing 777'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:10Z',
#      'local': '2025-12-13 01:40+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-12-13 06:35Z',
#      'local': '2025-12-13 06:35+00:00'},
#     'revisedTime': {'utc': '2025-12-13 06:39Z',
#      'local': '2025-12-13 06:39+00:00'},
#     'runwayTime': {'utc': '2025-12-13 06:39Z',
#      'local': '2025-12-13 06:39+00:00'},
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 161',
#    'callSign': 'AIC161',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-JRF',
#     'modeS': '801659',
#     'model': 'Airbus A350-900'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:15Z',
#      'local': '2025-12-13 01:45+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2025-12-13 05:20Z',
#      'local': '2025-12-13 06:20+01:00'},
#     'revisedTime': {'utc': '2025-12-13 05:28Z',
#      'local': '2025-12-13 06:28+01:00'},
#     'terminal': '2',
#     'baggageBelt': '21',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 147',
#    'callSign': 'SWR147',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JHC', 'modeS': '4B187C', 'model': 'Airbus A330'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:25Z',
#      'local': '2025-12-13 01:55+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2025-12-13 05:05Z',
#      'local': '2025-12-13 06:05+01:00'},
#     'revisedTime': {'utc': '2025-12-13 04:45Z',
#      'local': '2025-12-13 05:45+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 763',
#    'callSign': 'DLH763',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIMH',
#     'modeS': '3C65A8',
#     'model': 'Airbus A380-800'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z',
#      'local': '2025-12-13 02:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'KJFK',
#      'iata': 'JFK',
#      'name': 'New York',
#      'timeZone': 'America/New_York'},
#     'scheduledTime': {'utc': '2025-12-13 14:00Z',
#      'local': '2025-12-13 09:00-05:00'},
#     'revisedTime': {'utc': '2025-12-13 13:54Z',
#      'local': '2025-12-13 08:54-05:00'},
#     'runwayTime': {'utc': '2025-12-13 13:54Z',
#      'local': '2025-12-13 08:54-05:00'},
#     'terminal': '4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 101',
#    'callSign': 'AIC101',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-JRB',
#     'modeS': '801612',
#     'model': 'Airbus A350-900'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z',
#      'local': '2025-12-13 02:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VECC',
#      'iata': 'CCU',
#      'name': 'Kolkata',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-12 22:45Z',
#      'local': '2025-12-13 04:15+05:30'},
#     'quality': ['Basic']},
#    'number': 'AI 2702',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z',
#      'local': '2025-12-13 02:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VTSP',
#      'iata': 'HKT',
#      'name': 'Phuket',
#      'timeZone': 'Asia/Bangkok'},
#     'scheduledTime': {'utc': '2025-12-13 01:05Z',
#      'local': '2025-12-13 08:05+07:00'},
#     'revisedTime': {'utc': '2025-12-13 01:16Z',
#      'local': '2025-12-13 08:16+07:00'},
#     'terminal': 'D',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 2378',
#    'callSign': 'AIC2378',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-CIM',
#     'modeS': '800C85',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z',
#      'local': '2025-12-13 02:00+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'OIIE',
#      'iata': 'IKA',
#      'name': 'Tehran',
#      'timeZone': 'Asia/Tehran'},
#     'scheduledTime': {'utc': '2025-12-13 00:55Z',
#      'local': '2025-12-13 04:25+03:30'},
#     'quality': ['Basic']},
#    'number': 'W5 70',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'BAe 146-300'},
#    'airline': {'name': 'Mahan Air', 'iata': 'W5', 'icao': 'IRM'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z',
#      'local': '2025-12-13 02:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VOHS',
#      'iata': 'HYD',
#      'name': 'Hyderabad',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-12 22:45Z',
#      'local': '2025-12-13 04:15+05:30'},
#     'quality': ['Basic']},
#    'number': 'AI 2577',
#    'callSign': 'AIC2577',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '801603', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z',
#      'local': '2025-12-13 02:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VTBS',
#      'iata': 'BKK',
#      'name': 'Bangkok',
#      'timeZone': 'Asia/Bangkok'},
#     'scheduledTime': {'utc': '2025-12-13 00:50Z',
#      'local': '2025-12-13 07:50+07:00'},
#     'revisedTime': {'utc': '2025-12-13 00:26Z',
#      'local': '2025-12-13 07:26+07:00'},
#     'gate': 'F1',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 2336',
#    'callSign': 'AIC2336',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '801625', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:40Z',
#      'local': '2025-12-13 02:10+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VOMM',
#      'iata': 'MAA',
#      'name': 'Chennai',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-12 23:25Z',
#      'local': '2025-12-13 04:55+05:30'},
#     'terminal': '4',
#     'quality': ['Basic']},
#    'number': 'AI 2885',
#    'callSign': 'AIC2885',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-RTS',
#     'modeS': '801667',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:45Z',
#      'local': '2025-12-13 02:15+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'KEWR',
#      'iata': 'EWR',
#      'name': 'Newark',
#      'timeZone': 'America/New_York'},
#     'scheduledTime': {'utc': '2025-12-13 14:05Z',
#      'local': '2025-12-13 09:05-05:00'},
#     'revisedTime': {'utc': '2025-12-13 14:52Z',
#      'local': '2025-12-13 09:52-05:00'},
#     'runwayTime': {'utc': '2025-12-13 14:49Z',
#      'local': '2025-12-13 09:49-05:00'},
#     'terminal': 'B',
#     'runway': '22L',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 105',
#    'callSign': 'AIC105',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-JRH',
#     'modeS': '801666',
#     'model': 'Airbus A350-900'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:45Z',
#      'local': '2025-12-13 02:15+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VAPO',
#      'iata': 'PNQ',
#      'name': 'Pune',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-12 22:55Z',
#      'local': '2025-12-13 04:25+05:30'},
#     'quality': ['Basic']},
#    'number': '6E 2343',
#    'callSign': 'IGO2343',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '80160F', 'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 20:55Z',
#      'local': '2025-12-13 02:25+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'HAAB',
#      'iata': 'ADD',
#      'name': 'Addis Ababa',
#      'timeZone': 'Africa/Addis_Ababa'},
#     'scheduledTime': {'utc': '2025-12-13 03:30Z',
#      'local': '2025-12-13 06:30+03:00'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'ET 687',
#    'callSign': 'ETH687',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'ET-ARE', 'modeS': '040087', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Ethiopian', 'iata': 'ET', 'icao': 'ETH'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:00Z',
#      'local': '2025-12-13 02:30+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Chennay'}, 'quality': []},
#    'number': '6E 6828',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:00Z',
#      'local': '2025-12-13 02:30+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Chennay'}, 'quality': []},
#    'number': 'AI 891',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:00Z',
#      'local': '2025-12-13 02:30+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Kalkutta'}, 'quality': []},
#    'number': '6E 2788',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:25Z',
#      'local': '2025-12-13 02:55+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'WADD',
#      'iata': 'DPS',
#      'name': 'Denpasar-Bali Island',
#      'timeZone': 'Asia/Makassar'},
#     'scheduledTime': {'utc': '2025-12-13 05:50Z',
#      'local': '2025-12-13 13:50+08:00'},
#     'terminal': 'I',
#     'quality': ['Basic']},
#    'number': 'AI 2147',
#    'callSign': 'AIC2147',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-TVJ',
#     'modeS': '8015C5',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:30Z',
#      'local': '2025-12-13 03:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'OKBK',
#      'iata': 'KWI',
#      'name': 'Kuwait City',
#      'timeZone': 'Asia/Kuwait'},
#     'scheduledTime': {'utc': '2025-12-13 02:20Z',
#      'local': '2025-12-13 05:20+03:00'},
#     'terminal': '4',
#     'quality': ['Basic']},
#    'number': 'KU 382',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A330-900'},
#    'airline': {'name': 'Kuwait', 'iata': 'KU', 'icao': 'KAC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:50Z',
#      'local': '2025-12-13 03:20+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-12-13 07:45Z',
#      'local': '2025-12-13 07:45+00:00'},
#     'revisedTime': {'utc': '2025-12-13 06:59Z',
#      'local': '2025-12-13 06:59+00:00'},
#     'runwayTime': {'utc': '2025-12-13 06:59Z',
#      'local': '2025-12-13 06:59+00:00'},
#     'terminal': '5',
#     'baggageBelt': '4',
#     'runway': '27L',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 142',
#    'callSign': 'BAW142',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-XWBD',
#     'modeS': '40779A',
#     'model': 'Airbus A350-1000'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:50Z',
#      'local': '2025-12-13 03:20+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VABB',
#      'iata': 'BOM',
#      'name': 'Mumbai',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 00:05Z',
#      'local': '2025-12-13 05:35+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'AI 887',
#    'callSign': 'AIC887',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-AEH',
#     'modeS': '80153D',
#     'model': 'Boeing 777-200LR'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:50Z',
#      'local': '2025-12-13 03:20+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2025-12-13 07:05Z',
#      'local': '2025-12-13 08:05+01:00'},
#     'revisedTime': {'utc': '2025-12-13 06:29Z',
#      'local': '2025-12-13 07:29+01:00'},
#     'runwayTime': {'utc': '2025-12-13 06:29Z',
#      'local': '2025-12-13 07:29+01:00'},
#     'terminal': '3',
#     'gate': 'F5',
#     'baggageBelt': '17',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 872',
#    'callSign': 'KLM872',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BVR', 'modeS': '4851F5', 'model': 'Boeing 777'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:50Z',
#      'local': '2025-12-13 03:20+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'OMSJ',
#      'iata': 'SHJ',
#      'name': 'Sharjah',
#      'timeZone': 'Asia/Dubai'},
#     'scheduledTime': {'utc': '2025-12-13 01:50Z',
#      'local': '2025-12-13 05:50+04:00'},
#     'quality': ['Basic']},
#    'number': 'G9 464',
#    'callSign': 'ABY464',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '89671C', 'model': 'Airbus A320'},
#    'airline': {'name': 'Air Arabia', 'iata': 'G9', 'icao': 'ABY'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 21:55Z',
#      'local': '2025-12-13 03:25+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VCBI',
#      'iata': 'CMB',
#      'name': 'Colombo',
#      'timeZone': 'Asia/Colombo'},
#     'scheduledTime': {'utc': '2025-12-13 01:50Z',
#      'local': '2025-12-13 07:20+05:30'},
#     'quality': ['Basic']},
#    'number': 'AI 277',
#    'callSign': 'AIC277',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-SCV', 'modeS': '80053F', 'model': 'Airbus A319'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:00Z',
#      'local': '2025-12-13 03:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VTBS',
#      'iata': 'BKK',
#      'name': 'Bangkok',
#      'timeZone': 'Asia/Bangkok'},
#     'scheduledTime': {'utc': '2025-12-13 02:00Z',
#      'local': '2025-12-13 09:00+07:00'},
#     'revisedTime': {'utc': '2025-12-13 02:02Z',
#      'local': '2025-12-13 09:02+07:00'},
#     'gate': 'ARR',
#     'quality': ['Basic', 'Live']},
#    'number': 'TG 332',
#    'callSign': 'THA332',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HS-TXC', 'modeS': '885303', 'model': 'Airbus A320'},
#    'airline': {'name': 'Thai  International', 'iata': 'TG', 'icao': 'THA'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:05Z',
#      'local': '2025-12-13 03:35+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2025-12-13 07:05Z',
#      'local': '2025-12-13 08:05+01:00'},
#     'revisedTime': {'utc': '2025-12-13 06:50Z',
#      'local': '2025-12-13 07:50+01:00'},
#     'terminal': '1',
#     'gate': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 761',
#    'callSign': 'DLH761',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABVZ', 'modeS': '3C4ADA', 'model': 'Boeing 747'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:10Z',
#      'local': '2025-12-13 03:40+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LIRF',
#      'iata': 'FCO',
#      'name': 'Rome',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2025-12-13 07:15Z',
#      'local': '2025-12-13 08:15+01:00'},
#     'revisedTime': {'utc': '2025-12-13 07:46Z',
#      'local': '2025-12-13 08:46+01:00'},
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AZ 769',
#    'callSign': 'ITY769',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-HJO', 'modeS': '4CADC7', 'model': 'Airbus A330'},
#    'airline': {'name': 'ITA', 'iata': 'AZ', 'icao': 'ITY'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:15Z',
#      'local': '2025-12-13 03:45+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'OTHH',
#      'iata': 'DOH',
#      'name': 'Doha',
#      'timeZone': 'Asia/Qatar'},
#     'scheduledTime': {'utc': '2025-12-13 02:45Z',
#      'local': '2025-12-13 05:45+03:00'},
#     'revisedTime': {'utc': '2025-12-13 02:43Z',
#      'local': '2025-12-13 05:43+03:00'},
#     'runwayTime': {'utc': '2025-12-13 02:35Z',
#      'local': '2025-12-13 05:35+03:00'},
#     'baggageBelt': '7',
#     'quality': ['Basic', 'Live']},
#    'number': 'QR 579',
#    'callSign': 'QTR579',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'A7-ALB',
#     'modeS': '06A0F6',
#     'model': 'Airbus A350-900'},
#    'airline': {'name': 'Qatar', 'iata': 'QR', 'icao': 'QTR'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z',
#      'local': '2025-12-13 04:00+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VABB',
#      'iata': 'BOM',
#      'name': 'Mumbai',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 00:50Z',
#      'local': '2025-12-13 06:20+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': '6E 2766',
#    'callSign': 'IGO2766',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '80180B', 'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z',
#      'local': '2025-12-13 04:00+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VABB',
#      'iata': 'BOM',
#      'name': 'Mumbai',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 00:50Z',
#      'local': '2025-12-13 06:20+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': '6E 2766',
#    'callSign': 'IGO2766',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '80180B', 'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z',
#      'local': '2025-12-13 04:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2025-12-13 08:55Z',
#      'local': '2025-12-13 09:55+01:00'},
#     'revisedTime': {'utc': '2025-12-13 08:47Z',
#      'local': '2025-12-13 09:47+01:00'},
#     'terminal': '2C',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 147',
#    'callSign': 'AIC147',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-AND', 'modeS': '8005EE', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z',
#      'local': '2025-12-13 04:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2025-12-13 08:55Z',
#      'local': '2025-12-13 09:55+01:00'},
#     'revisedTime': {'utc': '2025-12-13 08:47Z',
#      'local': '2025-12-13 09:47+01:00'},
#     'terminal': '2C',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 147',
#    'callSign': 'AIC147',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-AND', 'modeS': '8005EE', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z',
#      'local': '2025-12-13 04:00+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VAPO',
#      'iata': 'PNQ',
#      'name': 'Pune',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 00:35Z',
#      'local': '2025-12-13 06:05+05:30'},
#     'quality': ['Basic']},
#    'number': 'IX 1230',
#    'callSign': 'AXB1230',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '80165C', 'model': 'Airbus A320'},
#    'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z',
#      'local': '2025-12-13 04:00+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VAPO',
#      'iata': 'PNQ',
#      'name': 'Pune',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 00:35Z',
#      'local': '2025-12-13 06:05+05:30'},
#     'quality': ['Basic']},
#    'number': 'IX 1230',
#    'callSign': 'AXB1230',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '80165C', 'model': 'Airbus A320'},
#    'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:35Z',
#      'local': '2025-12-13 04:05+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-12-13 09:30Z',
#      'local': '2025-12-13 09:30+00:00'},
#     'revisedTime': {'utc': '2025-12-13 09:37Z',
#      'local': '2025-12-13 09:37+00:00'},
#     'terminal': '2',
#     'gate': 'D8',
#     'quality': ['Basic', 'Live']},
#    'number': '6E 33',
#    'callSign': 'IGO0033',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LN-LNR', 'modeS': '47C98D', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:40Z',
#      'local': '2025-12-13 04:10+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'OMDB',
#      'iata': 'DXB',
#      'name': 'Dubai',
#      'timeZone': 'Asia/Dubai'},
#     'scheduledTime': {'utc': '2025-12-13 02:35Z',
#      'local': '2025-12-13 06:35+04:00'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'EK 513',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 777-300ER'},
#    'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:40Z',
#      'local': '2025-12-13 04:10+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'OERK',
#      'iata': 'RUH',
#      'name': 'Riyadh',
#      'timeZone': 'Asia/Riyadh'},
#     'scheduledTime': {'utc': '2025-12-13 03:55Z',
#      'local': '2025-12-13 06:55+03:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'XY 330',
#    'callSign': 'KNE330',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '71156D', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'flynas', 'iata': 'XY', 'icao': 'KNE'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:40Z',
#      'local': '2025-12-13 04:10+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VIAR',
#      'iata': 'ATQ',
#      'name': 'Amritsar',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-12 23:50Z',
#      'local': '2025-12-13 05:20+05:30'},
#     'quality': ['Basic']},
#    'number': 'IX 1683',
#    'callSign': 'AXB1683',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-ATD',
#     'modeS': '801403',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:55Z',
#      'local': '2025-12-13 04:25+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'OMAA',
#      'iata': 'AUH',
#      'name': 'Abu Dhabi Island and Internal Islands City',
#      'timeZone': 'Asia/Dubai'},
#     'scheduledTime': {'utc': '2025-12-13 02:55Z',
#      'local': '2025-12-13 06:55+04:00'},
#     'terminal': 'A',
#     'quality': ['Basic']},
#    'number': 'EY 219',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787'},
#    'airline': {'name': 'Etihad', 'iata': 'EY', 'icao': 'ETD'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:55Z',
#      'local': '2025-12-13 04:25+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'UBBB',
#      'iata': 'GYD',
#      'name': 'Baku',
#      'timeZone': 'Asia/Baku'},
#     'scheduledTime': {'utc': '2025-12-13 03:35Z',
#      'local': '2025-12-13 07:35+04:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'J2 58',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'AZAL Azerbaijan', 'iata': 'J2', 'icao': 'AHY'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 22:55Z',
#      'local': '2025-12-13 04:25+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2025-12-13 08:45Z',
#      'local': '2025-12-13 09:45+01:00'},
#     'revisedTime': {'utc': '2025-12-13 08:52Z',
#      'local': '2025-12-13 09:52+01:00'},
#     'runwayTime': {'utc': '2025-12-13 08:36Z',
#      'local': '2025-12-13 09:36+01:00'},
#     'terminal': '1',
#     'gate': 'B1',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 2025',
#    'callSign': 'AIC2025',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-TSH', 'modeS': '801406', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:00Z',
#      'local': '2025-12-13 04:30+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VAAH',
#      'iata': 'AMD',
#      'name': 'Ahmedabad',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 00:35Z',
#      'local': '2025-12-13 06:05+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': '6E 2308',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:00Z',
#      'local': '2025-12-13 04:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VOBL',
#      'iata': 'BLR',
#      'name': 'Bangalore',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 01:50Z',
#      'local': '2025-12-13 07:20+05:30'},
#     'revisedTime': {'utc': '2025-12-13 01:35Z',
#      'local': '2025-12-13 07:05+05:30'},
#     'terminal': '2',
#     'gate': 'D13',
#     'baggageBelt': '7A',
#     'quality': ['Basic', 'Live']},
#    'number': 'AI 2653',
#    'callSign': 'AIC2653',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-TQU',
#     'modeS': '80162F',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:00Z',
#      'local': '2025-12-13 04:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VNKT',
#      'iata': 'KTM',
#      'name': 'Kathmandu',
#      'timeZone': 'Asia/Kathmandu'},
#     'scheduledTime': {'utc': '2025-12-13 00:50Z',
#      'local': '2025-12-13 06:35+05:45'},
#     'terminal': 'I',
#     'quality': ['Basic']},
#    'number': 'AI 215',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:10Z',
#      'local': '2025-12-13 04:40+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Nagpur'}, 'quality': []},
#    'number': '6E 6820',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:10Z',
#      'local': '2025-12-13 04:40+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VAPO',
#      'iata': 'PNQ',
#      'name': 'Pune',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 01:25Z',
#      'local': '2025-12-13 06:55+05:30'},
#     'quality': ['Basic']},
#    'number': '6E 2471',
#    'callSign': 'IGO2471',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-ITL',
#     'modeS': '800BC0',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:15Z',
#      'local': '2025-12-13 04:45+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VAPO',
#      'iata': 'PNQ',
#      'name': 'Pune',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 01:25Z',
#      'local': '2025-12-13 06:55+05:30'},
#     'quality': ['Basic']},
#    'number': 'AI 2469',
#    'callSign': 'AIC2469',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '80162E', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:15Z',
#      'local': '2025-12-13 04:45+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Jaipur'}, 'quality': []},
#    'number': '6E 5037',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:15Z',
#      'local': '2025-12-13 04:45+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Hyderabad'}, 'quality': []},
#    'number': '6E 2255',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:25Z',
#      'local': '2025-12-13 04:55+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VOPB',
#      'iata': 'IXZ',
#      'name': 'Port Blair',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 03:10Z',
#      'local': '2025-12-13 08:40+05:30'},
#     'quality': ['Basic']},
#    'number': 'IX 1538',
#    'callSign': 'AXB1538',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '801626', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:25Z',
#      'local': '2025-12-13 04:55+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VIAR',
#      'iata': 'ATQ',
#      'name': 'Amritsar',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 00:55Z',
#      'local': '2025-12-13 06:25+05:30'},
#     'quality': ['Basic']},
#    'number': 'AI 1703',
#    'callSign': 'AIC1703',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '801584', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:25Z',
#      'local': '2025-12-13 04:55+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'name': 'Amritsar'}, 'quality': []},
#    'number': '6E 5103',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:30Z',
#      'local': '2025-12-13 05:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-12-13 09:30Z',
#      'local': '2025-12-13 09:30+00:00'},
#     'revisedTime': {'utc': '2025-12-13 08:37Z',
#      'local': '2025-12-13 08:37+00:00'},
#     'runwayTime': {'utc': '2025-12-13 08:37Z',
#      'local': '2025-12-13 08:37+00:00'},
#     'terminal': '3',
#     'baggageBelt': '01',
#     'runway': '27L',
#     'quality': ['Basic', 'Live']},
#    'number': 'VS 303',
#    'callSign': 'VIR303',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-VRNB',
#     'modeS': '4077D4',
#     'model': 'Airbus A350-1000'},
#    'airline': {'name': 'Virgin Atlantic', 'iata': 'VS', 'icao': 'VIR'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:30Z',
#      'local': '2025-12-13 05:00+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VOCI',
#      'iata': 'COK',
#      'name': 'Kochi',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 02:40Z',
#      'local': '2025-12-13 08:10+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': '6E 5273',
#    'callSign': 'IGO5273',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '80183A', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:30Z',
#      'local': '2025-12-13 05:00+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VOML',
#      'iata': 'IXE',
#      'name': 'Mangalore',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 02:30Z',
#      'local': '2025-12-13 08:00+05:30'},
#     'quality': ['Basic']},
#    'number': 'IX 1275',
#    'callSign': 'AXB1275',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '801607', 'model': 'Boeing 737'},
#    'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}},
#   {'departure': {'scheduledTime': {'utc': '2025-12-12 23:30Z',
#      'local': '2025-12-13 05:00+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'airport': {'icao': 'VEBS',
#      'iata': 'BBI',
#      'name': 'Bhubaneswar',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 01:35Z',
#      'local': '2025-12-13 07:05+05:30'},
#     'terminal': '1',
# ...
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'airport': {'icao': 'VOHS',
#      'iata': 'HYD',
#      'name': 'Hyderabad',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 03:30Z',
#      'local': '2025-12-13 09:00+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 05:50Z',
#      'local': '2025-12-13 11:20+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 2514',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'VARP',
#      'iata': 'RPR',
#      'name': 'Raipur',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 03:45Z',
#      'local': '2025-12-13 09:15+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 05:50Z',
#      'local': '2025-12-13 11:20+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': '6E 6476',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'airport': {'icao': 'VECC',
#      'iata': 'CCU',
#      'name': 'Kolkata',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 03:25Z',
#      'local': '2025-12-13 08:55+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 05:55Z',
#      'local': '2025-12-13 11:25+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'QP 1802',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737'},
#    'airline': {'name': 'Starlight Airline', 'iata': 'QP', 'icao': 'SLT'}},
#   {'departure': {'airport': {'icao': 'VOML',
#      'iata': 'IXE',
#      'name': 'Mangalore',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 03:00Z',
#      'local': '2025-12-13 08:30+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:00Z',
#      'local': '2025-12-13 11:30+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'IX 1276',
#    'callSign': 'AXB1276',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '801607', 'model': 'Boeing 737'},
#    'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}},
#   {'departure': {'airport': {'icao': 'WMKK',
#      'iata': 'KUL',
#      'name': 'Kuala Lumpur',
#      'timeZone': 'Asia/Kuala_Lumpur'},
#     'scheduledTime': {'utc': '2025-12-13 00:05Z',
#      'local': '2025-12-13 08:05+08:00'},
#     'revisedTime': {'utc': '2025-12-13 00:32Z',
#      'local': '2025-12-13 08:32+08:00'},
#     'terminal': '1',
#     'checkInDesk': 'L10',
#     'gate': 'G001C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:00Z',
#      'local': '2025-12-13 11:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 2385',
#    'callSign': 'AIC2385',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-EXP',
#     'modeS': '800CFE',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'VIBN',
#      'iata': 'VNS',
#      'name': 'Varanasi',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:25Z',
#      'local': '2025-12-13 09:55+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:00Z',
#      'local': '2025-12-13 11:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 2496',
#    'callSign': 'AIC2496',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-TVD', 'modeS': '801464', 'model': 'Airbus A321'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'UTTT',
#      'iata': 'TAS',
#      'name': 'Tashkent',
#      'timeZone': 'Asia/Tashkent'},
#     'scheduledTime': {'utc': '2025-12-13 03:10Z',
#      'local': '2025-12-13 08:10+05:00'},
#     'revisedTime': {'utc': '2025-12-13 03:43Z',
#      'local': '2025-12-13 08:43+05:00'},
#     'terminal': '2',
#     'checkInDesk': '35-40',
#     'gate': 'B1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:00Z',
#      'local': '2025-12-13 11:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'HY 423',
#    'callSign': 'UZB423',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'UK67005',
#     'modeS': '507C48',
#     'model': 'Boeing 767-300'},
#    'airline': {'name': 'Uzbekistan', 'iata': 'HY', 'icao': 'UZB'}},
#   {'departure': {'airport': {'icao': 'VOBZ',
#      'iata': 'VGA',
#      'name': 'Vidzhayavada',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 03:30Z',
#      'local': '2025-12-13 09:00+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:00Z',
#      'local': '2025-12-13 11:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 2572',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'VAAH',
#      'iata': 'AMD',
#      'name': 'Ahmedabad',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:15Z',
#      'local': '2025-12-13 09:45+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:00Z',
#      'local': '2025-12-13 11:30+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': '6E 5239',
#    'callSign': 'IGO5239',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '8015DB', 'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'airport': {'icao': 'VIBK',
#      'iata': 'BKB',
#      'name': 'Bikaner',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:40Z',
#      'local': '2025-12-13 10:10+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:00Z',
#      'local': '2025-12-13 11:30+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': '6E 7443',
#    'callSign': 'IGO7443',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-IYC', 'modeS': '800C6E', 'model': 'ATR 72'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'airport': {'icao': 'VIBN',
#      'iata': 'VNS',
#      'name': 'Varanasi',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:25Z',
#      'local': '2025-12-13 09:55+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:05Z',
#      'local': '2025-12-13 11:35+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'IX 1224',
#    'callSign': 'AXB1224',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '801606', 'model': 'Boeing 737'},
#    'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}},
#   {'departure': {'airport': {'icao': 'WSSS',
#      'iata': 'SIN',
#      'name': 'Singapore',
#      'timeZone': 'Asia/Singapore'},
#     'scheduledTime': {'utc': '2025-12-13 00:20Z',
#      'local': '2025-12-13 08:20+08:00'},
#     'revisedTime': {'utc': '2025-12-13 01:00Z',
#      'local': '2025-12-13 09:00+08:00'},
#     'runwayTime': {'utc': '2025-12-13 01:41Z',
#      'local': '2025-12-13 09:41+08:00'},
#     'terminal': '2',
#     'checkInDesk': '10',
#     'gate': 'F42',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:05Z',
#      'local': '2025-12-13 11:35+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 2381',
#    'callSign': 'AIC2381',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-TSP', 'modeS': '80158C', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'VAAH',
#      'iata': 'AMD',
#      'name': 'Ahmedabad',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:20Z',
#      'local': '2025-12-13 09:50+05:30'},
#     'revisedTime': {'utc': '2025-12-13 04:25Z',
#      'local': '2025-12-13 09:55+05:30'},
#     'runwayTime': {'utc': '2025-12-13 04:25Z',
#      'local': '2025-12-13 09:55+05:30'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:05Z',
#      'local': '2025-12-13 11:35+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 2946',
#    'callSign': 'AIC2946',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-CIE',
#     'modeS': '800BE6',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'VIJU',
#      'iata': 'IXJ',
#      'name': 'Jammu',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:45Z',
#      'local': '2025-12-13 10:15+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:10Z',
#      'local': '2025-12-13 11:40+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': '6E 6510',
#    'callSign': 'IGO6510',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '8015AD', 'model': 'Airbus A320'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'airport': {'icao': 'VIJO',
#      'iata': 'JDH',
#      'name': 'Jodhpur',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:50Z',
#      'local': '2025-12-13 10:20+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:10Z',
#      'local': '2025-12-13 11:40+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'IX 1980',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}},
#   {'departure': {'airport': {'icao': 'VIAR',
#      'iata': 'ATQ',
#      'name': 'Amritsar',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 05:00Z',
#      'local': '2025-12-13 10:30+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:10Z',
#      'local': '2025-12-13 11:40+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 496',
#    'callSign': 'AIC496',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-TVG',
#     'modeS': '80155F',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'VABB',
#      'iata': 'BOM',
#      'name': 'Mumbai',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:00Z',
#      'local': '2025-12-13 09:30+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:15Z',
#      'local': '2025-12-13 11:45+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 2432',
#    'callSign': 'AIC2432',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-TQH',
#     'modeS': '80145A',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'VOTP',
#      'iata': 'TIR',
#      'name': 'Tirumala - Tirupati',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 03:30Z',
#      'local': '2025-12-13 09:00+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:15Z',
#      'local': '2025-12-13 11:45+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': '6E 6490',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'airport': {'icao': 'VNKT',
#      'iata': 'KTM',
#      'name': 'Kathmandu',
#      'timeZone': 'Asia/Kathmandu'},
#     'scheduledTime': {'utc': '2025-12-13 04:20Z',
#      'local': '2025-12-13 10:05+05:45'},
#     'terminal': 'I',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:20Z',
#      'local': '2025-12-13 11:50+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 214',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'VAUD',
#      'iata': 'UDR',
#      'name': 'Udaipur',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:40Z',
#      'local': '2025-12-13 10:10+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:20Z',
#      'local': '2025-12-13 11:50+05:30'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'number': 'AI 1840',
#    'callSign': 'AIC1840',
#    'status': 'Unknown',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'modeS': '80164F', 'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}},
#   {'departure': {'airport': {'icao': 'VIAR',
#      'iata': 'ATQ',
#      'name': 'Amritsar',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 05:10Z',
#      'local': '2025-12-13 10:40+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:25Z',
#      'local': '2025-12-13 11:55+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': '6E 6848',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'airport': {'icao': 'VAJB',
#      'iata': 'JLR',
#      'name': 'Dzhabalpur',
#      'timeZone': 'Asia/Kolkata'},
#     'scheduledTime': {'utc': '2025-12-13 04:40Z',
#      'local': '2025-12-13 10:10+05:30'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:25Z',
#      'local': '2025-12-13 11:55+05:30'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': '6E 6267',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}},
#   {'departure': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2025-12-12 21:05Z',
#      'local': '2025-12-12 21:05+00:00'},
#     'revisedTime': {'utc': '2025-12-12 22:10Z',
#      'local': '2025-12-12 22:10+00:00'},
#     'runwayTime': {'utc': '2025-12-12 22:13Z',
#      'local': '2025-12-12 22:13+00:00'},
#     'terminal': '2',
#     'checkInDesk': 'B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2025-12-13 06:25Z',
#      'local': '2025-12-13 11:55+05:30'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'number': 'AI 2018',
#    'callSign': 'AIC2018',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'VT-TSP', 'modeS': '80158C', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}]}

# %%
pd.DataFrame(airport_flights["departures"])
# Out:
#                                              departure  \
# 0    {'scheduledTime': {'utc': '2025-12-12 18:35Z',...
# 1    {'scheduledTime': {'utc': '2025-12-12 18:35Z',...
# 2    {'scheduledTime': {'utc': '2025-12-12 18:45Z',...
# 3    {'scheduledTime': {'utc': '2025-12-12 18:45Z',...
# 4    {'scheduledTime': {'utc': '2025-12-12 18:45Z',...
# ..                                                 ...
# 698  {'scheduledTime': {'utc': '2025-12-13 18:05Z',...
# 699  {'scheduledTime': {'utc': '2025-12-13 18:15Z',...
# 700  {'scheduledTime': {'utc': '2025-12-13 18:20Z',...
# 701  {'scheduledTime': {'utc': '2025-12-13 18:25Z',...
# 702  {'scheduledTime': {'utc': '2025-12-13 18:25Z',...
#
#                                                arrival   number callSign  \
# 0    {'airport': {'icao': 'VABB', 'iata': 'BOM', 'n...  AI 2451  AIC2451
# 1    {'airport': {'icao': 'VVTS', 'iata': 'SGN', 'n...   VJ 896   VJC896
# 2    {'airport': {'icao': 'VOBL', 'iata': 'BLR', 'n...  AI 2757  AIC2757
# 3    {'airport': {'icao': 'VHHH', 'iata': 'HKG', 'n...  6E 1707  IGO1707
# 4    {'airport': {'icao': 'RKSI', 'iata': 'ICN', 'n...   AI 312   AIC312
# ..                                                 ...      ...      ...
# 698  {'airport': {'icao': 'VVTS', 'iata': 'SGN', 'n...   VN 976      NaN
# 699       {'airport': {'name': 'Pune'}, 'quality': []}  6E 6410      NaN
# 700  {'airport': {'icao': 'VAPO', 'iata': 'PNQ', 'n...  AI 2609      NaN
# 701  {'airport': {'icao': 'KEWR', 'iata': 'EWR', 'n...    UA 83      NaN
# 702  {'airport': {'icao': 'KJFK', 'iata': 'JFK', 'n...   AA 293      NaN
#
#        status codeshareStatus  isCargo  \
# 0     Unknown      IsOperator    False
# 1     Unknown      IsOperator    False
# 2    Departed      IsOperator    False
# 3    Departed      IsOperator    False
# 4    Departed      IsOperator    False
# ..        ...             ...      ...
# 698   Unknown         Unknown    False
# 699   Unknown         Unknown    False
# 700   Unknown         Unknown    False
# 701   Unknown      IsOperator    False
# 702   Unknown         Unknown    False
#
#                                               aircraft  \
# 0      {'modeS': '801672', 'model': 'Airbus A320 NEO'}
# 1    {'reg': 'VN-A812', 'modeS': '8881C7', 'model':...
# 2    {'reg': 'VT-TNU', 'modeS': '8013A3', 'model': ...
# 3          {'modeS': '801536', 'model': 'Airbus A320'}
# 4    {'reg': 'VT-ANX', 'modeS': '80073E', 'model': ...
# ..                                                 ...
# 698                       {'model': 'Airbus A350-900'}
# 699                           {'model': 'Airbus A320'}
# 700                       {'model': 'Airbus A320 NEO'}
# 701                          {'model': 'Boeing 787-9'}
# 702                          {'model': 'Boeing 787-9'}
#
#                                                airline location
# 0    {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# 1    {'name': 'VietJetAir', 'iata': 'VJ', 'icao': '...      NaN
# 2    {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# 3      {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
# 4    {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# ..                                                 ...      ...
# 698   {'name': 'Vietnam', 'iata': 'VN', 'icao': 'HVN'}      NaN
# 699    {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
# 700  {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# 701    {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}      NaN
# 702  {'name': 'American', 'iata': 'AA', 'icao': 'AAL'}      NaN
#
# [703 rows x 10 columns]

# %%
pd.DataFrame(airport_flights["arrivals"])
# Out:
#                                              departure  \
# 0    {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'n...
# 1    {'airport': {'icao': 'VIAR', 'iata': 'ATQ', 'n...
# 2    {'airport': {'icao': 'VARP', 'iata': 'RPR', 'n...
# 3    {'airport': {'icao': 'VOVZ', 'iata': 'VTZ', 'n...
# 4    {'airport': {'icao': 'VHHH', 'iata': 'HKG', 'n...
# ..                                                 ...
# 636  {'airport': {'icao': 'VOBL', 'iata': 'BLR', 'n...
# 637  {'airport': {'icao': 'VTSP', 'iata': 'HKT', 'n...
# 638  {'airport': {'icao': 'VILK', 'iata': 'LKO', 'n...
# 639  {'airport': {'icao': 'VOCI', 'iata': 'COK', 'n...
# 640  {'airport': {'icao': 'OMDB', 'iata': 'DXB', 'n...
#
#                                                arrival   number callSign  \
# 0    {'scheduledTime': {'utc': '2025-12-12 18:35Z',...   LH 762   DLH762
# 1    {'scheduledTime': {'utc': '2025-12-12 18:35Z',...  6E 5215      NaN
# 2    {'scheduledTime': {'utc': '2025-12-12 18:35Z',...  6E 2473      NaN
# 3    {'scheduledTime': {'utc': '2025-12-12 18:40Z',...  AI 1802      NaN
# 4    {'scheduledTime': {'utc': '2025-12-12 18:40Z',...   CX 679   CPA679
# ..                                                 ...      ...      ...
# 636  {'scheduledTime': {'utc': '2025-12-13 18:25Z',...  AI 2661      NaN
# 637  {'scheduledTime': {'utc': '2025-12-13 18:25Z',...  AI 2377      NaN
# 638  {'scheduledTime': {'utc': '2025-12-13 18:25Z',...  AI 1821      NaN
# 639  {'scheduledTime': {'utc': '2025-12-13 18:25Z',...  6E 5274      NaN
# 640  {'scheduledTime': {'utc': '2025-12-13 18:25Z',...  6E 1464      NaN
#
#        status codeshareStatus  isCargo  \
# 0    Expected      IsOperator    False
# 1     Unknown      IsOperator    False
# 2     Unknown         Unknown    False
# 3     Unknown         Unknown    False
# 4    Expected      IsOperator    False
# ..        ...             ...      ...
# 636  Expected      IsOperator    False
# 637  Expected      IsOperator    False
# 638   Unknown         Unknown    False
# 639   Unknown         Unknown    False
# 640   Unknown         Unknown    False
#
#                                               aircraft  \
# 0    {'reg': 'D-AIMH', 'modeS': '3C65A8', 'model': ...
# 1                         {'model': 'Airbus A320 NEO'}
# 2                         {'model': 'Airbus A320 NEO'}
# 3                         {'model': 'Airbus A320 NEO'}
# 4    {'reg': 'B-LQH', 'modeS': '789276', 'model': '...
# ..                                                 ...
# 636  {'reg': 'VT-EXQ', 'modeS': '800CFF', 'model': ...
# 637                       {'model': 'Airbus A320 NEO'}
# 638                       {'model': 'Airbus A320 NEO'}
# 639                       {'model': 'Airbus A320 NEO'}
# 640                           {'model': 'Airbus A320'}
#
#                                                airline location
# 0    {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'D...      NaN
# 1      {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
# 2      {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
# 3    {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# 4    {'name': 'Cathay Pacific', 'iata': 'CX', 'icao...      NaN
# ..                                                 ...      ...
# 636  {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# 637  {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# 638  {'name': 'Air India', 'iata': 'AI', 'icao': 'A...      NaN
# 639    {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
# 640    {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}      NaN
#
# [641 rows x 10 columns]

# %%
with open("airport_del_flights.json", "w") as f:
    import json
    json.dump(airport_flights, f, indent=4)

# %%
from db_connection import get_connection
conn = get_connection()

# %%
def safe_str(value):
    if isinstance(value, (dict, list)):
        return str(value)
    return value

# %%
def insert_flight(conn, f):
    cur = conn.cursor()

    dep = f.get("departure", {})
    arr = f.get("arrival", {})
    aircraft = f.get("aircraft", {})

    # print("""
    #     INSERT OR IGNORE INTO flights
    #     (flight_id, flight_number, aircraft_registration,
    #      origin_iata, destination_iata,
    #      scheduled_departure, actual_departure,
    #      scheduled_arrival, actual_arrival,
    #      status, airline_code)
    #     VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    # """, (
    #     safe_str(f.get("number")),
    #     safe_str(f.get("number")),
    #     safe_str(aircraft.get("reg")),
    #     safe_str(dep.get("airport", {}).get("iata") or "DEL"),
    #     safe_str(arr.get("airport", {}).get("iata") or "DEL"),
    #     safe_str(dep.get("scheduledTime", {}).get("utc", "")),
    #     safe_str(dep.get("actualTimeLocal")),
    #     safe_str(arr.get("scheduledTime", {}).get("utc", "")),
    #     safe_str(arr.get("actualTimeLocal")),
    #     safe_str(f.get("status")),
    #     safe_str(f.get("airline", {}).get("iata"))
    # ))

    cur.execute("""
        INSERT OR IGNORE INTO flights
        (flight_id, flight_number, aircraft_registration,
         origin_iata, destination_iata,
         scheduled_departure, actual_departure,
         scheduled_arrival, actual_arrival,
         status, airline_code)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, (
        safe_str(f.get("number")),
        safe_str(f.get("number")),
        safe_str(aircraft.get("reg")),
        safe_str(dep.get("airport", {}).get("iata") or "DEL"),
        safe_str(arr.get("airport", {}).get("iata") or "DEL"),
        safe_str(dep.get("scheduledTime", {}).get("utc", "")),
        safe_str(dep.get("actualTimeLocal")),
        safe_str(arr.get("scheduledTime", {}).get("utc", "")),
        safe_str(arr.get("actualTimeLocal")),
        safe_str(f.get("status")),
        safe_str(f.get("airline", {}).get("iata"))
    ))

    # conn.commit()

# %%
f = {'departure': {'airport': {'icao': 'VARP', 'iata': 'RPR', 'name': 'Raipur', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-12 16:30Z', 'local': '2025-12-12 22:00+05:30'}, 'quality': ['Basic']}, 'arrival': {'scheduledTime': {'utc': '2025-12-12 18:35Z', 'local': '2025-12-13 00:05+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': '6E 2473', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}

f = {'departure': {'scheduledTime': {'utc': '2025-12-12 18:35Z', 'local': '2025-12-13 00:05+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VVTS', 'iata': 'SGN', 'name': 'Ho Chi Minh City', 'timeZone': 'Asia/Ho_Chi_Minh'}, 'scheduledTime': {'utc': '2025-12-12 23:20Z', 'local': '2025-12-13 06:20+07:00'}, 'terminal': '2', 'quality': ['Basic']}, 'number': 'VJ 896', 'callSign': 'VJC896', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VN-A812', 'modeS': '8881C7', 'model': 'Airbus A330-300'}, 'airline': {'name': 'VietJetAir', 'iata': 'VJ', 'icao': 'VJC'}}


insert_flight(conn, f)

# %%
for f in airport_flights["departures"]:
    print(f)
    # insert_flight(conn, f)
# Out:
# {'departure': {'scheduledTime': {'utc': '2025-12-12 18:35Z', 'local': '2025-12-13 00:05+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VABB', 'iata': 'BOM', 'name': 'Mumbai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-12 20:55Z', 'local': '2025-12-13 02:25+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': 'AI 2451', 'callSign': 'AIC2451', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '801672', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 18:35Z', 'local': '2025-12-13 00:05+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VVTS', 'iata': 'SGN', 'name': 'Ho Chi Minh City', 'timeZone': 'Asia/Ho_Chi_Minh'}, 'scheduledTime': {'utc': '2025-12-12 23:20Z', 'local': '2025-12-13 06:20+07:00'}, 'terminal': '2', 'quality': ['Basic']}, 'number': 'VJ 896', 'callSign': 'VJC896', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VN-A812', 'modeS': '8881C7', 'model': 'Airbus A330-300'}, 'airline': {'name': 'VietJetAir', 'iata': 'VJ', 'icao': 'VJC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 18:45Z', 'local': '2025-12-13 00:15+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOBL', 'iata': 'BLR', 'name': 'Bangalore', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-12 21:40Z', 'local': '2025-12-13 03:10+05:30'}, 'revisedTime': {'utc': '2025-12-12 22:06Z', 'local': '2025-12-13 03:36+05:30'}, 'terminal': '2', 'baggageBelt': '8A', 'quality': ['Basic', 'Live']}, 'number': 'AI 2757', 'callSign': 'AIC2757', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-TNU', 'modeS': '8013A3', 'model': 'Airbus A321 (Sharklets)'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 18:45Z', 'local': '2025-12-13 00:15+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VHHH', 'iata': 'HKG', 'name': 'Hong Kong', 'timeZone': 'Asia/Shanghai'}, 'scheduledTime': {'utc': '2025-12-12 23:55Z', 'local': '2025-12-13 07:55+08:00'}, 'revisedTime': {'utc': '2025-12-12 23:33Z', 'local': '2025-12-13 07:33+08:00'}, 'terminal': '1', 'gate': 'N10', 'baggageBelt': '14', 'quality': ['Basic', 'Live']}, 'number': '6E 1707', 'callSign': 'IGO1707', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '801536', 'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 18:45Z', 'local': '2025-12-13 00:15+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'RKSI', 'iata': 'ICN', 'name': 'Seoul', 'timeZone': 'Asia/Seoul'}, 'scheduledTime': {'utc': '2025-12-13 01:30Z', 'local': '2025-12-13 10:30+09:00'}, 'revisedTime': {'utc': '2025-12-13 01:23Z', 'local': '2025-12-13 10:23+09:00'}, 'runwayTime': {'utc': '2025-12-13 01:23Z', 'local': '2025-12-13 10:23+09:00'}, 'terminal': '1', 'gate': '39', 'baggageBelt': '21', 'quality': ['Basic', 'Live']}, 'number': 'AI 312', 'callSign': 'AIC312', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-ANX', 'modeS': '80073E', 'model': 'Boeing 787-8'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 18:50Z', 'local': '2025-12-13 00:20+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VTBS', 'iata': 'BKK', 'name': 'Bangkok', 'timeZone': 'Asia/Bangkok'}, 'scheduledTime': {'utc': '2025-12-12 23:05Z', 'local': '2025-12-13 06:05+07:00'}, 'revisedTime': {'utc': '2025-12-12 23:00Z', 'local': '2025-12-13 06:00+07:00'}, 'gate': 'D2', 'quality': ['Basic', 'Live']}, 'number': 'TG 316', 'callSign': 'THA316', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'HS-TKL', 'modeS': '88516C', 'model': 'Boeing 777'}, 'airline': {'name': 'Thai  International', 'iata': 'TG', 'icao': 'THA'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 18:55Z', 'local': '2025-12-13 00:25+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'CYUL', 'iata': 'YUL', 'name': 'Montreal', 'timeZone': 'America/Toronto'}, 'scheduledTime': {'utc': '2025-12-13 11:10Z', 'local': '2025-12-13 06:10-05:00'}, 'revisedTime': {'utc': '2025-12-13 11:14Z', 'local': '2025-12-13 06:14-05:00'}, 'gate': '66', 'quality': ['Basic', 'Live']}, 'number': 'AC 51', 'callSign': 'ACA51', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'C-FVLZ', 'modeS': 'C038AC', 'model': 'Boeing 787-9'}, 'airline': {'name': 'Air Canada', 'iata': 'AC', 'icao': 'ACA'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 19:00Z', 'local': '2025-12-13 00:30+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'name': 'Mumbai'}, 'quality': []}, 'number': '6E 6787', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 19:25Z', 'local': '2025-12-13 00:55+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'YSSY', 'iata': 'SYD', 'name': 'Sydney', 'timeZone': 'Australia/Sydney'}, 'scheduledTime': {'utc': '2025-12-13 08:15Z', 'local': '2025-12-13 19:15+11:00'}, 'revisedTime': {'utc': '2025-12-13 07:49Z', 'local': '2025-12-13 18:49+11:00'}, 'runwayTime': {'utc': '2025-12-13 07:45Z', 'local': '2025-12-13 18:45+11:00'}, 'terminal': '1', 'runway': '34L', 'quality': ['Basic', 'Live']}, 'number': 'AI 302', 'callSign': 'AIC302', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-NAC', 'modeS': '800742', 'model': 'Boeing 787-8'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 19:55Z', 'local': '2025-12-13 01:25+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'YMML', 'iata': 'MEL', 'name': 'Melbourne', 'timeZone': 'Australia/Melbourne'}, 'scheduledTime': {'utc': '2025-12-13 07:55Z', 'local': '2025-12-13 18:55+11:00'}, 'revisedTime': {'utc': '2025-12-13 08:21Z', 'local': '2025-12-13 19:21+11:00'}, 'runwayTime': {'utc': '2025-12-13 08:09Z', 'local': '2025-12-13 19:09+11:00'}, 'terminal': '2', 'gate': '9', 'runway': '27', 'quality': ['Basic', 'Live']}, 'number': 'AI 308', 'callSign': 'AIC308', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-ANA', 'modeS': '8005EB', 'model': 'Boeing 787-8'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:00Z', 'local': '2025-12-13 01:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VHHH', 'iata': 'HKG', 'name': 'Hong Kong', 'timeZone': 'Asia/Shanghai'}, 'scheduledTime': {'utc': '2025-12-13 01:25Z', 'local': '2025-12-13 09:25+08:00'}, 'revisedTime': {'utc': '2025-12-13 02:23Z', 'local': '2025-12-13 10:23+08:00'}, 'terminal': '1', 'gate': 'S33', 'baggageBelt': '17', 'quality': ['Basic', 'Live']}, 'number': 'CX 694', 'callSign': 'CPA694', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'B-LQH', 'modeS': '789276', 'model': 'Airbus A350-900'}, 'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:00Z', 'local': '2025-12-13 01:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris', 'timeZone': 'Europe/Paris'}, 'scheduledTime': {'utc': '2025-12-13 05:15Z', 'local': '2025-12-13 06:15+01:00'}, 'revisedTime': {'utc': '2025-12-13 05:06Z', 'local': '2025-12-13 06:06+01:00'}, 'terminal': '2E', 'quality': ['Basic', 'Live']}, 'number': 'AF 225', 'callSign': 'AFR225', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'F-HRBB', 'modeS': '39C421', 'model': 'Boeing 787-9'}, 'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:05Z', 'local': '2025-12-13 01:35+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna', 'timeZone': 'Europe/Vienna'}, 'scheduledTime': {'utc': '2025-12-13 05:18Z', 'local': '2025-12-13 06:18+01:00'}, 'revisedTime': {'utc': '2025-12-13 05:31Z', 'local': '2025-12-13 06:31+01:00'}, 'runwayTime': {'utc': '2025-12-13 05:18Z', 'local': '2025-12-13 06:18+01:00'}, 'runway': '16', 'quality': ['Basic', 'Live']}, 'number': 'AI 187', 'callSign': 'AIC187', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-ALR', 'modeS': '8004E0', 'model': 'Boeing 777'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:10Z', 'local': '2025-12-13 01:40+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London', 'timeZone': 'Europe/London'}, 'scheduledTime': {'utc': '2025-12-13 06:35Z', 'local': '2025-12-13 06:35+00:00'}, 'revisedTime': {'utc': '2025-12-13 06:39Z', 'local': '2025-12-13 06:39+00:00'}, 'runwayTime': {'utc': '2025-12-13 06:39Z', 'local': '2025-12-13 06:39+00:00'}, 'terminal': '2', 'baggageBelt': '8', 'quality': ['Basic', 'Live']}, 'number': 'AI 161', 'callSign': 'AIC161', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-JRF', 'modeS': '801659', 'model': 'Airbus A350-900'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:15Z', 'local': '2025-12-13 01:45+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich', 'timeZone': 'Europe/Zurich'}, 'scheduledTime': {'utc': '2025-12-13 05:20Z', 'local': '2025-12-13 06:20+01:00'}, 'revisedTime': {'utc': '2025-12-13 05:28Z', 'local': '2025-12-13 06:28+01:00'}, 'terminal': '2', 'baggageBelt': '21', 'quality': ['Basic', 'Live']}, 'number': 'LX 147', 'callSign': 'SWR147', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'HB-JHC', 'modeS': '4B187C', 'model': 'Airbus A330'}, 'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:25Z', 'local': '2025-12-13 01:55+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich', 'timeZone': 'Europe/Berlin'}, 'scheduledTime': {'utc': '2025-12-13 05:05Z', 'local': '2025-12-13 06:05+01:00'}, 'revisedTime': {'utc': '2025-12-13 04:45Z', 'local': '2025-12-13 05:45+01:00'}, 'terminal': '2', 'quality': ['Basic', 'Live']}, 'number': 'LH 763', 'callSign': 'DLH763', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'D-AIMH', 'modeS': '3C65A8', 'model': 'Airbus A380-800'}, 'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VTSP', 'iata': 'HKT', 'name': 'Phuket', 'timeZone': 'Asia/Bangkok'}, 'scheduledTime': {'utc': '2025-12-13 01:05Z', 'local': '2025-12-13 08:05+07:00'}, 'revisedTime': {'utc': '2025-12-13 01:16Z', 'local': '2025-12-13 08:16+07:00'}, 'terminal': 'D', 'quality': ['Basic', 'Live']}, 'number': 'AI 2378', 'callSign': 'AIC2378', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-CIM', 'modeS': '800C85', 'model': 'Airbus A321 (Sharklets)'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VTBS', 'iata': 'BKK', 'name': 'Bangkok', 'timeZone': 'Asia/Bangkok'}, 'scheduledTime': {'utc': '2025-12-13 00:50Z', 'local': '2025-12-13 07:50+07:00'}, 'revisedTime': {'utc': '2025-12-13 00:26Z', 'local': '2025-12-13 07:26+07:00'}, 'gate': 'F1', 'quality': ['Basic', 'Live']}, 'number': 'AI 2336', 'callSign': 'AIC2336', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '801625', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOHS', 'iata': 'HYD', 'name': 'Hyderabad', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-12 22:45Z', 'local': '2025-12-13 04:15+05:30'}, 'quality': ['Basic']}, 'number': 'AI 2577', 'callSign': 'AIC2577', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '801603', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'KJFK', 'iata': 'JFK', 'name': 'New York', 'timeZone': 'America/New_York'}, 'scheduledTime': {'utc': '2025-12-13 14:00Z', 'local': '2025-12-13 09:00-05:00'}, 'terminal': '4', 'quality': ['Basic']}, 'number': 'AI 101', 'callSign': 'AIC101', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-JRB', 'modeS': '801612', 'model': 'Airbus A350-900'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}, 'location': {'pressureAltitude': {'meter': 10523.22, 'km': 10.52, 'mile': 6.54, 'nm': 5.68, 'feet': 34525.0}, 'altitude': {'meter': 10523.22, 'km': 10.52, 'mile': 6.54, 'nm': 5.68, 'feet': 34525.0}, 'pressure': {'hPa': 0.0, 'inHg': 0.0, 'mmHg': 0.0}, 'groundSpeed': {'kt': 405.0, 'kmPerHour': 750.0, 'miPerHour': 466.0, 'meterPerSecond': 208.0}, 'trueTrack': {'deg': 199.2, 'rad': 3.4766958167094826}, 'reportedAtUtc': '2025-12-13 13:15Z', 'lat': 41.961548, 'lon': -71.31888}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'}, 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'OIIE', 'iata': 'IKA', 'name': 'Tehran', 'timeZone': 'Asia/Tehran'}, 'scheduledTime': {'utc': '2025-12-13 00:55Z', 'local': '2025-12-13 04:25+03:30'}, 'quality': ['Basic']}, 'number': 'W5 70', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'BAe 146-300'}, 'airline': {'name': 'Mahan Air', 'iata': 'W5', 'icao': 'IRM'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VECC', 'iata': 'CCU', 'name': 'Kolkata', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-12 22:45Z', 'local': '2025-12-13 04:15+05:30'}, 'quality': ['Basic']}, 'number': 'AI 2702', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:40Z', 'local': '2025-12-13 02:10+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOMM', 'iata': 'MAA', 'name': 'Chennai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-12 23:25Z', 'local': '2025-12-13 04:55+05:30'}, 'terminal': '4', 'quality': ['Basic']}, 'number': 'AI 2885', 'callSign': 'AIC2885', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-RTS', 'modeS': '801667', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:45Z', 'local': '2025-12-13 02:15+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'KEWR', 'iata': 'EWR', 'name': 'Newark', 'timeZone': 'America/New_York'}, 'scheduledTime': {'utc': '2025-12-13 14:05Z', 'local': '2025-12-13 09:05-05:00'}, 'terminal': 'B', 'quality': ['Basic']}, 'number': 'AI 105', 'callSign': 'AIC105', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-JRH', 'modeS': '801666', 'model': 'Airbus A350-900'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}, 'location': {'pressureAltitude': {'meter': 12184.38, 'km': 12.18, 'mile': 7.57, 'nm': 6.58, 'feet': 39975.0}, 'altitude': {'meter': 12184.38, 'km': 12.18, 'mile': 7.57, 'nm': 6.58, 'feet': 39975.0}, 'pressure': {'hPa': 0.0, 'inHg': 0.0, 'mmHg': 0.0}, 'groundSpeed': {'kt': 453.0, 'kmPerHour': 839.0, 'miPerHour': 521.0, 'meterPerSecond': 233.0}, 'trueTrack': {'deg': 223.0, 'rad': 3.8920842319473548}, 'reportedAtUtc': '2025-12-13 13:15Z', 'lat': 47.92397, 'lon': -66.56383}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:45Z', 'local': '2025-12-13 02:15+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VAPO', 'iata': 'PNQ', 'name': 'Pune', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-12 22:55Z', 'local': '2025-12-13 04:25+05:30'}, 'quality': ['Basic']}, 'number': '6E 2343', 'callSign': 'IGO2343', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '80160F', 'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 20:55Z', 'local': '2025-12-13 02:25+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'HAAB', 'iata': 'ADD', 'name': 'Addis Ababa', 'timeZone': 'Africa/Addis_Ababa'}, 'scheduledTime': {'utc': '2025-12-13 03:30Z', 'local': '2025-12-13 06:30+03:00'}, 'terminal': '2', 'quality': ['Basic']}, 'number': 'ET 687', 'callSign': 'ETH687', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'ET-ARE', 'modeS': '040087', 'model': 'Boeing 787-8'}, 'airline': {'name': 'Ethiopian', 'iata': 'ET', 'icao': 'ETH'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:00Z', 'local': '2025-12-13 02:30+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'name': 'Chennay'}, 'quality': []}, 'number': 'AI 891', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:00Z', 'local': '2025-12-13 02:30+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOMM', 'iata': 'MAA', 'name': 'Chennai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-12 23:50Z', 'local': '2025-12-13 05:20+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'number': '6E 6828', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:00Z', 'local': '2025-12-13 02:30+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'name': 'Kalkutta'}, 'quality': []}, 'number': '6E 2788', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:25Z', 'local': '2025-12-13 02:55+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'WADD', 'iata': 'DPS', 'name': 'Denpasar-Bali Island', 'timeZone': 'Asia/Makassar'}, 'scheduledTime': {'utc': '2025-12-13 05:50Z', 'local': '2025-12-13 13:50+08:00'}, 'terminal': 'I', 'quality': ['Basic']}, 'number': 'AI 2147', 'callSign': 'AIC2147', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-TVJ', 'modeS': '8015C5', 'model': 'Airbus A321 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:30Z', 'local': '2025-12-13 03:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'OKBK', 'iata': 'KWI', 'name': 'Kuwait City', 'timeZone': 'Asia/Kuwait'}, 'scheduledTime': {'utc': '2025-12-13 02:20Z', 'local': '2025-12-13 05:20+03:00'}, 'terminal': '4', 'quality': ['Basic']}, 'number': 'KU 382', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A330-900'}, 'airline': {'name': 'Kuwait', 'iata': 'KU', 'icao': 'KAC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:50Z', 'local': '2025-12-13 03:20+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam', 'timeZone': 'Europe/Amsterdam'}, 'scheduledTime': {'utc': '2025-12-13 07:05Z', 'local': '2025-12-13 08:05+01:00'}, 'revisedTime': {'utc': '2025-12-13 06:29Z', 'local': '2025-12-13 07:29+01:00'}, 'runwayTime': {'utc': '2025-12-13 06:29Z', 'local': '2025-12-13 07:29+01:00'}, 'terminal': '3', 'gate': 'F5', 'baggageBelt': '17', 'quality': ['Basic', 'Live']}, 'number': 'KL 872', 'callSign': 'KLM872', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'PH-BVR', 'modeS': '4851F5', 'model': 'Boeing 777'}, 'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:50Z', 'local': '2025-12-13 03:20+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'OMSJ', 'iata': 'SHJ', 'name': 'Sharjah', 'timeZone': 'Asia/Dubai'}, 'scheduledTime': {'utc': '2025-12-13 01:50Z', 'local': '2025-12-13 05:50+04:00'}, 'quality': ['Basic']}, 'number': 'G9 464', 'callSign': 'ABY464', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '89671C', 'model': 'Airbus A320'}, 'airline': {'name': 'Air Arabia', 'iata': 'G9', 'icao': 'ABY'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:50Z', 'local': '2025-12-13 03:20+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London', 'timeZone': 'Europe/London'}, 'scheduledTime': {'utc': '2025-12-13 07:45Z', 'local': '2025-12-13 07:45+00:00'}, 'revisedTime': {'utc': '2025-12-13 06:59Z', 'local': '2025-12-13 06:59+00:00'}, 'runwayTime': {'utc': '2025-12-13 06:59Z', 'local': '2025-12-13 06:59+00:00'}, 'terminal': '5', 'baggageBelt': '4', 'runway': '27L', 'quality': ['Basic', 'Live']}, 'number': 'BA 142', 'callSign': 'BAW142', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'G-XWBD', 'modeS': '40779A', 'model': 'Airbus A350-1000'}, 'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:50Z', 'local': '2025-12-13 03:20+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VABB', 'iata': 'BOM', 'name': 'Mumbai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 00:05Z', 'local': '2025-12-13 05:35+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': 'AI 887', 'callSign': 'AIC887', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-AEH', 'modeS': '80153D', 'model': 'Boeing 777-200LR'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 21:55Z', 'local': '2025-12-13 03:25+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VCBI', 'iata': 'CMB', 'name': 'Colombo', 'timeZone': 'Asia/Colombo'}, 'scheduledTime': {'utc': '2025-12-13 01:50Z', 'local': '2025-12-13 07:20+05:30'}, 'quality': ['Basic']}, 'number': 'AI 277', 'callSign': 'AIC277', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-SCV', 'modeS': '80053F', 'model': 'Airbus A319'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:00Z', 'local': '2025-12-13 03:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VTBS', 'iata': 'BKK', 'name': 'Bangkok', 'timeZone': 'Asia/Bangkok'}, 'scheduledTime': {'utc': '2025-12-13 02:00Z', 'local': '2025-12-13 09:00+07:00'}, 'revisedTime': {'utc': '2025-12-13 02:02Z', 'local': '2025-12-13 09:02+07:00'}, 'gate': 'ARR', 'quality': ['Basic', 'Live']}, 'number': 'TG 332', 'callSign': 'THA332', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'HS-TXC', 'modeS': '885303', 'model': 'Airbus A320'}, 'airline': {'name': 'Thai  International', 'iata': 'TG', 'icao': 'THA'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:05Z', 'local': '2025-12-13 03:35+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'EDDF', 'iata': 'FRA', 'name': 'Frankfurt-am-Main', 'timeZone': 'Europe/Berlin'}, 'scheduledTime': {'utc': '2025-12-13 07:05Z', 'local': '2025-12-13 08:05+01:00'}, 'revisedTime': {'utc': '2025-12-13 06:50Z', 'local': '2025-12-13 07:50+01:00'}, 'terminal': '1', 'gate': 'A2', 'quality': ['Basic', 'Live']}, 'number': 'LH 761', 'callSign': 'DLH761', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'D-ABVZ', 'modeS': '3C4ADA', 'model': 'Boeing 747'}, 'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:10Z', 'local': '2025-12-13 03:40+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'LIRF', 'iata': 'FCO', 'name': 'Rome', 'timeZone': 'Europe/Rome'}, 'scheduledTime': {'utc': '2025-12-13 07:15Z', 'local': '2025-12-13 08:15+01:00'}, 'revisedTime': {'utc': '2025-12-13 07:46Z', 'local': '2025-12-13 08:46+01:00'}, 'terminal': '3', 'quality': ['Basic', 'Live']}, 'number': 'AZ 769', 'callSign': 'ITY769', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'EI-HJO', 'modeS': '4CADC7', 'model': 'Airbus A330'}, 'airline': {'name': 'ITA', 'iata': 'AZ', 'icao': 'ITY'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:15Z', 'local': '2025-12-13 03:45+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'OTHH', 'iata': 'DOH', 'name': 'Doha', 'timeZone': 'Asia/Qatar'}, 'scheduledTime': {'utc': '2025-12-13 02:45Z', 'local': '2025-12-13 05:45+03:00'}, 'revisedTime': {'utc': '2025-12-13 02:43Z', 'local': '2025-12-13 05:43+03:00'}, 'runwayTime': {'utc': '2025-12-13 02:35Z', 'local': '2025-12-13 05:35+03:00'}, 'baggageBelt': '7', 'quality': ['Basic', 'Live']}, 'number': 'QR 579', 'callSign': 'QTR579', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'A7-ALB', 'modeS': '06A0F6', 'model': 'Airbus A350-900'}, 'airline': {'name': 'Qatar', 'iata': 'QR', 'icao': 'QTR'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VABB', 'iata': 'BOM', 'name': 'Mumbai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 00:50Z', 'local': '2025-12-13 06:20+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': '6E 2766', 'callSign': 'IGO2766', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '80180B', 'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VABB', 'iata': 'BOM', 'name': 'Mumbai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 00:50Z', 'local': '2025-12-13 06:20+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': '6E 2766', 'callSign': 'IGO2766', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '80180B', 'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VAPO', 'iata': 'PNQ', 'name': 'Pune', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 00:35Z', 'local': '2025-12-13 06:05+05:30'}, 'quality': ['Basic']}, 'number': 'IX 1230', 'callSign': 'AXB1230', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '80165C', 'model': 'Airbus A320'}, 'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VAPO', 'iata': 'PNQ', 'name': 'Pune', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 00:35Z', 'local': '2025-12-13 06:05+05:30'}, 'quality': ['Basic']}, 'number': 'IX 1230', 'callSign': 'AXB1230', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '80165C', 'model': 'Airbus A320'}, 'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris', 'timeZone': 'Europe/Paris'}, 'scheduledTime': {'utc': '2025-12-13 08:55Z', 'local': '2025-12-13 09:55+01:00'}, 'revisedTime': {'utc': '2025-12-13 08:47Z', 'local': '2025-12-13 09:47+01:00'}, 'terminal': '2C', 'quality': ['Basic', 'Live']}, 'number': 'AI 147', 'callSign': 'AIC147', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-AND', 'modeS': '8005EE', 'model': 'Boeing 787-8'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris', 'timeZone': 'Europe/Paris'}, 'scheduledTime': {'utc': '2025-12-13 08:55Z', 'local': '2025-12-13 09:55+01:00'}, 'revisedTime': {'utc': '2025-12-13 08:47Z', 'local': '2025-12-13 09:47+01:00'}, 'terminal': '2C', 'quality': ['Basic', 'Live']}, 'number': 'AI 147', 'callSign': 'AIC147', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-AND', 'modeS': '8005EE', 'model': 'Boeing 787-8'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:35Z', 'local': '2025-12-13 04:05+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'EGCC', 'iata': 'MAN', 'name': 'Manchester', 'timeZone': 'Europe/London'}, 'scheduledTime': {'utc': '2025-12-13 09:30Z', 'local': '2025-12-13 09:30+00:00'}, 'revisedTime': {'utc': '2025-12-13 09:37Z', 'local': '2025-12-13 09:37+00:00'}, 'terminal': '2', 'gate': 'D8', 'quality': ['Basic', 'Live']}, 'number': '6E 33', 'callSign': 'IGO0033', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'LN-LNR', 'modeS': '47C98D', 'model': 'Boeing 787-9'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:40Z', 'local': '2025-12-13 04:10+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'OMDB', 'iata': 'DXB', 'name': 'Dubai', 'timeZone': 'Asia/Dubai'}, 'scheduledTime': {'utc': '2025-12-13 02:35Z', 'local': '2025-12-13 06:35+04:00'}, 'terminal': '3', 'quality': ['Basic']}, 'number': 'EK 513', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Boeing 777-300ER'}, 'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:40Z', 'local': '2025-12-13 04:10+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'OERK', 'iata': 'RUH', 'name': 'Riyadh', 'timeZone': 'Asia/Riyadh'}, 'scheduledTime': {'utc': '2025-12-13 03:55Z', 'local': '2025-12-13 06:55+03:00'}, 'terminal': '1', 'quality': ['Basic']}, 'number': 'XY 330', 'callSign': 'KNE330', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '71156D', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'flynas', 'iata': 'XY', 'icao': 'KNE'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:40Z', 'local': '2025-12-13 04:10+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VIAR', 'iata': 'ATQ', 'name': 'Amritsar', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-12 23:50Z', 'local': '2025-12-13 05:20+05:30'}, 'quality': ['Basic']}, 'number': 'IX 1683', 'callSign': 'AXB1683', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-ATD', 'modeS': '801403', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:55Z', 'local': '2025-12-13 04:25+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'UBBB', 'iata': 'GYD', 'name': 'Baku', 'timeZone': 'Asia/Baku'}, 'scheduledTime': {'utc': '2025-12-13 03:35Z', 'local': '2025-12-13 07:35+04:00'}, 'terminal': '1', 'quality': ['Basic']}, 'number': 'J2 58', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'AZAL Azerbaijan', 'iata': 'J2', 'icao': 'AHY'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:55Z', 'local': '2025-12-13 04:25+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'EDDF', 'iata': 'FRA', 'name': 'Frankfurt-am-Main', 'timeZone': 'Europe/Berlin'}, 'scheduledTime': {'utc': '2025-12-13 08:45Z', 'local': '2025-12-13 09:45+01:00'}, 'revisedTime': {'utc': '2025-12-13 08:52Z', 'local': '2025-12-13 09:52+01:00'}, 'runwayTime': {'utc': '2025-12-13 08:36Z', 'local': '2025-12-13 09:36+01:00'}, 'terminal': '1', 'gate': 'B1', 'runway': '25L', 'quality': ['Basic', 'Live']}, 'number': 'AI 2025', 'callSign': 'AIC2025', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-TSH', 'modeS': '801406', 'model': 'Boeing 787-9'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 22:55Z', 'local': '2025-12-13 04:25+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'OMAA', 'iata': 'AUH', 'name': 'Abu Dhabi Island and Internal Islands City', 'timeZone': 'Asia/Dubai'}, 'scheduledTime': {'utc': '2025-12-13 02:55Z', 'local': '2025-12-13 06:55+04:00'}, 'terminal': 'A', 'quality': ['Basic']}, 'number': 'EY 219', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Boeing 787'}, 'airline': {'name': 'Etihad', 'iata': 'EY', 'icao': 'ETD'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:00Z', 'local': '2025-12-13 04:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOBL', 'iata': 'BLR', 'name': 'Bangalore', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 01:50Z', 'local': '2025-12-13 07:20+05:30'}, 'revisedTime': {'utc': '2025-12-13 01:35Z', 'local': '2025-12-13 07:05+05:30'}, 'terminal': '2', 'gate': 'D13', 'baggageBelt': '7A', 'quality': ['Basic', 'Live']}, 'number': 'AI 2653', 'callSign': 'AIC2653', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-TQU', 'modeS': '80162F', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:00Z', 'local': '2025-12-13 04:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VNKT', 'iata': 'KTM', 'name': 'Kathmandu', 'timeZone': 'Asia/Kathmandu'}, 'scheduledTime': {'utc': '2025-12-13 00:50Z', 'local': '2025-12-13 06:35+05:45'}, 'terminal': 'I', 'quality': ['Basic']}, 'number': 'AI 215', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:00Z', 'local': '2025-12-13 04:30+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VAAH', 'iata': 'AMD', 'name': 'Ahmedabad', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 00:35Z', 'local': '2025-12-13 06:05+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'number': '6E 2308', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:10Z', 'local': '2025-12-13 04:40+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'name': 'Nagpur'}, 'quality': []}, 'number': '6E 6820', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:10Z', 'local': '2025-12-13 04:40+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VAPO', 'iata': 'PNQ', 'name': 'Pune', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 01:25Z', 'local': '2025-12-13 06:55+05:30'}, 'quality': ['Basic']}, 'number': '6E 2471', 'callSign': 'IGO2471', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-ITL', 'modeS': '800BC0', 'model': 'Airbus A320 (Sharklets)'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:15Z', 'local': '2025-12-13 04:45+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VAPO', 'iata': 'PNQ', 'name': 'Pune', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 01:25Z', 'local': '2025-12-13 06:55+05:30'}, 'quality': ['Basic']}, 'number': 'AI 2469', 'callSign': 'AIC2469', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '80162E', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:15Z', 'local': '2025-12-13 04:45+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOHS', 'iata': 'HYD', 'name': 'Hyderabad', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 01:25Z', 'local': '2025-12-13 06:55+05:30'}, 'quality': ['Basic']}, 'number': '6E 2255', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:15Z', 'local': '2025-12-13 04:45+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'name': 'Jaipur'}, 'quality': []}, 'number': '6E 5037', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:25Z', 'local': '2025-12-13 04:55+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOPB', 'iata': 'IXZ', 'name': 'Port Blair', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 03:10Z', 'local': '2025-12-13 08:40+05:30'}, 'quality': ['Basic']}, 'number': 'IX 1538', 'callSign': 'AXB1538', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '801626', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:25Z', 'local': '2025-12-13 04:55+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VIAR', 'iata': 'ATQ', 'name': 'Amritsar', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 00:55Z', 'local': '2025-12-13 06:25+05:30'}, 'quality': ['Basic']}, 'number': 'AI 1703', 'callSign': 'AIC1703', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '801584', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:25Z', 'local': '2025-12-13 04:55+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'name': 'Amritsar'}, 'quality': []}, 'number': '6E 5103', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:30Z', 'local': '2025-12-13 05:00+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VEBS', 'iata': 'BBI', 'name': 'Bhubaneswar', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 01:35Z', 'local': '2025-12-13 07:05+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'number': '6E 508', 'callSign': 'IGO508', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'TC-TJR', 'modeS': '4BD152', 'model': 'Boeing 737'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:30Z', 'local': '2025-12-13 05:00+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'name': 'Mumbai'}, 'quality': []}, 'number': '6E 449', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:30Z', 'local': '2025-12-13 05:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOCI', 'iata': 'COK', 'name': 'Kochi', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 02:40Z', 'local': '2025-12-13 08:10+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'number': '6E 5273', 'callSign': 'IGO5273', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '80183A', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:30Z', 'local': '2025-12-13 05:00+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOML', 'iata': 'IXE', 'name': 'Mangalore', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 02:30Z', 'local': '2025-12-13 08:00+05:30'}, 'quality': ['Basic']}, 'number': 'IX 1275', 'callSign': 'AXB1275', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '801607', 'model': 'Boeing 737'}, 'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:30Z', 'local': '2025-12-13 05:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London', 'timeZone': 'Europe/London'}, 'scheduledTime': {'utc': '2025-12-13 09:30Z', 'local': '2025-12-13 09:30+00:00'}, 'revisedTime': {'utc': '2025-12-13 08:37Z', 'local': '2025-12-13 08:37+00:00'}, 'runwayTime': {'utc': '2025-12-13 08:37Z', 'local': '2025-12-13 08:37+00:00'}, 'terminal': '3', 'baggageBelt': '01', 'runway': '27L', 'quality': ['Basic', 'Live']}, 'number': 'VS 303', 'callSign': 'VIR303', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'G-VRNB', 'modeS': '4077D4', 'model': 'Airbus A350-1000'}, 'airline': {'name': 'Virgin Atlantic', 'iata': 'VS', 'icao': 'VIR'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:40Z', 'local': '2025-12-13 05:10+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VCBI', 'iata': 'CMB', 'name': 'Colombo', 'timeZone': 'Asia/Colombo'}, 'scheduledTime': {'utc': '2025-12-13 03:15Z', 'local': '2025-12-13 08:45+05:30'}, 'quality': ['Basic']}, 'number': 'UL 192', 'callSign': 'ALK192', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': '4R-ANA', 'modeS': '7705C1', 'model': 'Airbus A321 (Sharklets)'}, 'airline': {'name': 'SriLankan', 'iata': 'UL', 'icao': 'ALK'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:45Z', 'local': '2025-12-13 05:15+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VECC', 'iata': 'CCU', 'name': 'Kolkata', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 01:55Z', 'local': '2025-12-13 07:25+05:30'}, 'quality': ['Basic']}, 'number': '6E 5014', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:45Z', 'local': '2025-12-13 05:15+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VEBD', 'iata': 'IXB', 'name': 'Siliguri', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 02:00Z', 'local': '2025-12-13 07:30+05:30'}, 'quality': ['Basic']}, 'number': 'SG 903', 'callSign': 'SEJ903', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-MXI', 'modeS': '800D1B', 'model': 'Boeing 737 MAX 8'}, 'airline': {'name': 'SpiceJet', 'iata': 'SG', 'icao': 'SEJ'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:45Z', 'local': '2025-12-13 05:15+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOGA', 'iata': 'GOX', 'name': 'Mopa', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 02:15Z', 'local': '2025-12-13 07:45+05:30'}, 'quality': ['Basic']}, 'number': '6E 2301', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:50Z', 'local': '2025-12-13 05:20+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOCB', 'iata': 'CJB', 'name': 'Coimbatore', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 02:45Z', 'local': '2025-12-13 08:15+05:30'}, 'quality': ['Basic']}, 'number': '6E 2275', 'callSign': 'IGO2275', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'modeS': '80184B', 'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-12 23:50Z', 'local': '2025-12-13 05:20+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOMD', 'iata': 'IXM', 'name': 'Madurai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 03:00Z', 'local': '2025-12-13 08:30+05:30'}, 'quality': ['Basic']}, 'number': '6E 2059', 'callSign': 'IGO2059', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-IUM', 'modeS': '8013C6', 'model': 'Airbus A321 NEO'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# ...
# {'departure': {'scheduledTime': {'utc': '2025-12-13 16:45Z', 'local': '2025-12-13 22:15+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VABB', 'iata': 'BOM', 'name': 'Mumbai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 19:20Z', 'local': '2025-12-14 00:50+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': '6E 6114', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 16:50Z', 'local': '2025-12-13 22:20+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VAAH', 'iata': 'AMD', 'name': 'Ahmedabad', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 18:35Z', 'local': '2025-12-14 00:05+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': 'SG 8193', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Boeing 737-800'}, 'airline': {'name': 'SpiceJet', 'iata': 'SG', 'icao': 'SEJ'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 16:50Z', 'local': '2025-12-13 22:20+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOBL', 'iata': 'BLR', 'name': 'Bangalore', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 19:45Z', 'local': '2025-12-14 01:15+05:30'}, 'revisedTime': {'utc': '2025-12-13 19:35Z', 'local': '2025-12-14 01:05+05:30'}, 'terminal': '2', 'gate': 'D8', 'baggageBelt': '7A', 'quality': ['Basic', 'Live']}, 'number': 'IX 1056', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-BXL', 'modeS': '80165E', 'model': 'Boeing 737'}, 'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:00Z', 'local': '2025-12-13 22:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'name': 'Ahmedabad'}, 'quality': []}, 'number': 'QP 1146', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Starlight Airline', 'iata': 'QP', 'icao': 'SLT'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:00Z', 'local': '2025-12-13 22:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VAAH', 'iata': 'AMD', 'name': 'Ahmedabad', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 18:50Z', 'local': '2025-12-14 00:20+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'number': 'AI 2909', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:00Z', 'local': '2025-12-13 22:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VABB', 'iata': 'BOM', 'name': 'Mumbai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 19:25Z', 'local': '2025-12-14 00:55+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': 'AI 2437', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:05Z', 'local': '2025-12-13 22:35+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VECC', 'iata': 'CCU', 'name': 'Kolkata', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 19:30Z', 'local': '2025-12-14 01:00+05:30'}, 'quality': ['Basic']}, 'number': 'SG 185', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Boeing 737-800'}, 'airline': {'name': 'SpiceJet', 'iata': 'SG', 'icao': 'SEJ'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:15Z', 'local': '2025-12-13 22:45+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOBL', 'iata': 'BLR', 'name': 'Bangalore', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 20:40Z', 'local': '2025-12-14 02:10+05:30'}, 'revisedTime': {'utc': '2025-12-13 20:06Z', 'local': '2025-12-14 01:36+05:30'}, 'terminal': '1', 'gate': 'A7', 'baggageBelt': '02', 'quality': ['Basic', 'Live']}, 'number': 'QP 1812', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'VT-YAU', 'modeS': '80161E', 'model': 'Boeing 737'}, 'airline': {'name': 'Starlight Airline', 'iata': 'QP', 'icao': 'SLT'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:15Z', 'local': '2025-12-13 22:45+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VILK', 'iata': 'LKO', 'name': 'Lucknow', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 18:35Z', 'local': '2025-12-14 00:05+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'number': 'IX 1040', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:15Z', 'local': '2025-12-13 22:45+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VHHH', 'iata': 'HKG', 'name': 'Hong Kong', 'timeZone': 'Asia/Shanghai'}, 'scheduledTime': {'utc': '2025-12-13 22:15Z', 'local': '2025-12-14 06:15+08:00'}, 'revisedTime': {'utc': '2025-12-13 22:15Z', 'local': '2025-12-14 06:15+08:00'}, 'terminal': '1', 'quality': ['Basic', 'Live']}, 'number': 'CX 698', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Airbus A350-900'}, 'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:15Z', 'local': '2025-12-13 22:45+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VHHH', 'iata': 'HKG', 'name': 'Hong Kong', 'timeZone': 'Asia/Shanghai'}, 'scheduledTime': {'utc': '2025-12-13 22:20Z', 'local': '2025-12-14 06:20+08:00'}, 'revisedTime': {'utc': '2025-12-13 22:20Z', 'local': '2025-12-14 06:20+08:00'}, 'terminal': '1', 'quality': ['Basic', 'Live']}, 'number': 'AI 314', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Boeing 787-8'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:20Z', 'local': '2025-12-13 22:50+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'WMKK', 'iata': 'KUL', 'name': 'Kuala Lumpur', 'timeZone': 'Asia/Kuala_Lumpur'}, 'scheduledTime': {'utc': '2025-12-13 23:00Z', 'local': '2025-12-14 07:00+08:00'}, 'revisedTime': {'utc': '2025-12-13 23:00Z', 'local': '2025-12-14 07:00+08:00'}, 'terminal': '1', 'quality': ['Basic', 'Live']}, 'number': 'AI 2386', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:25Z', 'local': '2025-12-13 22:55+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOHS', 'iata': 'HYD', 'name': 'Hyderabad', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 19:45Z', 'local': '2025-12-14 01:15+05:30'}, 'quality': ['Basic']}, 'number': 'AI 1706', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:30Z', 'local': '2025-12-13 23:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VABB', 'iata': 'BOM', 'name': 'Mumbai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 19:55Z', 'local': '2025-12-14 01:25+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': 'AI 2439', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:30Z', 'local': '2025-12-13 23:00+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'WSSS', 'iata': 'SIN', 'name': 'Singapore', 'timeZone': 'Asia/Singapore'}, 'scheduledTime': {'utc': '2025-12-13 23:00Z', 'local': '2025-12-14 07:00+08:00'}, 'revisedTime': {'utc': '2025-12-13 23:00Z', 'local': '2025-12-14 07:00+08:00'}, 'terminal': '2', 'quality': ['Basic', 'Live']}, 'number': 'AI 2380', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Boeing 787-9'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:30Z', 'local': '2025-12-13 23:00+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOBL', 'iata': 'BLR', 'name': 'Bangalore', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 20:25Z', 'local': '2025-12-14 01:55+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'number': '6E 6131', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:30Z', 'local': '2025-12-13 23:00+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOMM', 'iata': 'MAA', 'name': 'Chennai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 20:25Z', 'local': '2025-12-14 01:55+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'number': '6E 2386', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:30Z', 'local': '2025-12-13 23:00+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VOHS', 'iata': 'HYD', 'name': 'Hyderabad', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 19:40Z', 'local': '2025-12-14 01:10+05:30'}, 'quality': ['Basic']}, 'number': '6E 2253', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 17:40Z', 'local': '2025-12-13 23:10+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'WMKK', 'iata': 'KUL', 'name': 'Kuala Lumpur', 'timeZone': 'Asia/Kuala_Lumpur'}, 'scheduledTime': {'utc': '2025-12-13 23:05Z', 'local': '2025-12-14 07:05+08:00'}, 'revisedTime': {'utc': '2025-12-13 23:05Z', 'local': '2025-12-14 07:05+08:00'}, 'terminal': '1', 'quality': ['Basic', 'Live']}, 'number': 'MH 191', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Airbus A330-300'}, 'airline': {'name': 'Malaysia', 'iata': 'MH', 'icao': 'MAS'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 18:00Z', 'local': '2025-12-13 23:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VDTI', 'iata': 'KTI', 'name': 'Phnom Penh', 'timeZone': 'Asia/Phnom_Penh'}, 'scheduledTime': {'utc': '2025-12-13 23:05Z', 'local': '2025-12-14 06:05+07:00'}, 'quality': ['Basic']}, 'number': 'K6 761', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'Cambodia Angkor Air', 'iata': 'K6', 'icao': 'KHV'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 18:00Z', 'local': '2025-12-13 23:30+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'CYYZ', 'iata': 'YYZ', 'name': 'Toronto', 'timeZone': 'America/Toronto'}, 'scheduledTime': {'utc': '2025-12-14 10:45Z', 'local': '2025-12-14 05:45-05:00'}, 'revisedTime': {'utc': '2025-12-14 10:45Z', 'local': '2025-12-14 05:45-05:00'}, 'terminal': '1', 'gate': '178', 'baggageBelt': '6', 'quality': ['Basic', 'Live']}, 'number': 'AC 43', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Boeing 777-200LR'}, 'airline': {'name': 'Air Canada', 'iata': 'AC', 'icao': 'ACA'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 18:00Z', 'local': '2025-12-13 23:30+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VABB', 'iata': 'BOM', 'name': 'Mumbai', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 20:35Z', 'local': '2025-12-14 02:05+05:30'}, 'terminal': '2', 'quality': ['Basic']}, 'number': '6E 519', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 18:05Z', 'local': '2025-12-13 23:35+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VVTS', 'iata': 'SGN', 'name': 'Ho Chi Minh City', 'timeZone': 'Asia/Ho_Chi_Minh'}, 'scheduledTime': {'utc': '2025-12-13 22:55Z', 'local': '2025-12-14 05:55+07:00'}, 'terminal': '2', 'quality': ['Basic']}, 'number': 'VN 976', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A350-900'}, 'airline': {'name': 'Vietnam', 'iata': 'VN', 'icao': 'HVN'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 18:15Z', 'local': '2025-12-13 23:45+05:30'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'airport': {'name': 'Pune'}, 'quality': []}, 'number': '6E 6410', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320'}, 'airline': {'name': 'IndiGo', 'iata': '6E', 'icao': 'IGO'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 18:20Z', 'local': '2025-12-13 23:50+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'VAPO', 'iata': 'PNQ', 'name': 'Pune', 'timeZone': 'Asia/Kolkata'}, 'scheduledTime': {'utc': '2025-12-13 20:35Z', 'local': '2025-12-14 02:05+05:30'}, 'quality': ['Basic']}, 'number': 'AI 2609', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Air India', 'iata': 'AI', 'icao': 'AIC'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 18:25Z', 'local': '2025-12-13 23:55+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'KEWR', 'iata': 'EWR', 'name': 'Newark', 'timeZone': 'America/New_York'}, 'scheduledTime': {'utc': '2025-12-14 11:25Z', 'local': '2025-12-14 06:25-05:00'}, 'terminal': 'B', 'quality': ['Basic']}, 'number': 'UA 83', 'status': 'Unknown', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Boeing 787-9'}, 'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}}
# {'departure': {'scheduledTime': {'utc': '2025-12-13 18:25Z', 'local': '2025-12-13 23:55+05:30'}, 'terminal': '3', 'quality': ['Basic']}, 'arrival': {'airport': {'icao': 'KJFK', 'iata': 'JFK', 'name': 'New York', 'timeZone': 'America/New_York'}, 'scheduledTime': {'utc': '2025-12-14 11:10Z', 'local': '2025-12-14 06:10-05:00'}, 'terminal': '8', 'quality': ['Basic']}, 'number': 'AA 293', 'status': 'Unknown', 'codeshareStatus': 'Unknown', 'isCargo': False, 'aircraft': {'model': 'Boeing 787-9'}, 'airline': {'name': 'American', 'iata': 'AA', 'icao': 'AAL'}}

# %%
len(airport_flights["arrivals"])
# Out:
# 641

# %%
import requests
from datetime import datetime, timedelta
import pytz

def fetch_delays_full_day(iata: str, date_str: str):
    airport_tz = pytz.timezone("Asia/Kolkata")

    start_day = airport_tz.localize(
        datetime.strptime(date_str, "%Y-%m-%d")
    )
    end_day = start_day + timedelta(days=1)

    # IMPORTANT: start from +2h
    current = start_day + timedelta(hours=2)

    windows = []

    while current <= end_day:
        start_ts = current.strftime("%Y-%m-%dT%H:%M")
        url = f"https://{API_HOST}/airports/iata/{iata}/delays/{start_ts}"

        r = requests.get(url, headers=HEADERS)
        if r.status_code != 200:
            current += timedelta(hours=2)
            continue

        windows.append({
            "requested_ts": start_ts,
            "data": r.json()
        })

        current += timedelta(hours=2)

    return windows

# %%
result = fetch_delays_full_day("DEL", "2025-12-13")
print("\nTOTAL WINDOWS WITH DELAYS:", result)
# Out:
# TOTAL WINDOWS WITH DELAYS: [{'requested_ts': '2025-12-13T02:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-12 18:30Z', 'local': '2025-12-13 00:00+05:30'}, 'to': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'}, 'departuresDelayInformation': {'numTotal': 16, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 42, 'numQualifiedTotal': 0, 'numCancelled': 0}}}, {'requested_ts': '2025-12-13T04:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'}, 'to': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'}, 'departuresDelayInformation': {'numTotal': 23, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 28, 'numQualifiedTotal': 0, 'numCancelled': 0}}}, {'requested_ts': '2025-12-13T06:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'}, 'to': {'utc': '2025-12-13 00:30Z', 'local': '2025-12-13 06:00+05:30'}, 'departuresDelayInformation': {'numTotal': 54, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 15, 'numQualifiedTotal': 0, 'numCancelled': 0}}}, {'requested_ts': '2025-12-13T08:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-13 00:30Z', 'local': '2025-12-13 06:00+05:30'}, 'to': {'utc': '2025-12-13 02:30Z', 'local': '2025-12-13 08:00+05:30'}, 'departuresDelayInformation': {'numTotal': 70, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 18, 'numQualifiedTotal': 0, 'numCancelled': 0}}}, {'requested_ts': '2025-12-13T10:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-13 02:30Z', 'local': '2025-12-13 08:00+05:30'}, 'to': {'utc': '2025-12-13 04:30Z', 'local': '2025-12-13 10:00+05:30'}, 'departuresDelayInformation': {'numTotal': 59, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 59, 'numQualifiedTotal': 0, 'numCancelled': 0}}}, {'requested_ts': '2025-12-13T12:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-13 04:30Z', 'local': '2025-12-13 10:00+05:30'}, 'to': {'utc': '2025-12-13 06:30Z', 'local': '2025-12-13 12:00+05:30'}, 'departuresDelayInformation': {'numTotal': 69, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 68, 'numQualifiedTotal': 0, 'numCancelled': 0}}}, {'requested_ts': '2025-12-13T14:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-13 06:30Z', 'local': '2025-12-13 12:00+05:30'}, 'to': {'utc': '2025-12-13 08:30Z', 'local': '2025-12-13 14:00+05:30'}, 'departuresDelayInformation': {'numTotal': 61, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 59, 'numQualifiedTotal': 1, 'numCancelled': 0}}}, {'requested_ts': '2025-12-13T16:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-13 08:30Z', 'local': '2025-12-13 14:00+05:30'}, 'to': {'utc': '2025-12-13 10:30Z', 'local': '2025-12-13 16:00+05:30'}, 'departuresDelayInformation': {'numTotal': 63, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 66, 'numQualifiedTotal': 1, 'numCancelled': 0}}}, {'requested_ts': '2025-12-13T18:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-13 10:30Z', 'local': '2025-12-13 16:00+05:30'}, 'to': {'utc': '2025-12-13 12:30Z', 'local': '2025-12-13 18:00+05:30'}, 'departuresDelayInformation': {'numTotal': 60, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 71, 'numQualifiedTotal': 1, 'numCancelled': 0}}}, {'requested_ts': '2025-12-13T20:00', 'data': {'airportIcao': 'VIDP', 'from': {'utc': '2025-12-13 12:30Z', 'local': '2025-12-13 18:00+05:30'}, 'to': {'utc': '2025-12-13 14:30Z', 'local': '2025-12-13 20:00+05:30'}, 'departuresDelayInformation': {'numTotal': 60, 'numQualifiedTotal': 0, 'numCancelled': 0}, 'arrivalsDelayInformation': {'numTotal': 57, 'numQualifiedTotal': 0, 'numCancelled': 0}}}, {'requested_ts': '2025 ...

# %%
result
# Out:
# [{'requested_ts': '2025-12-13T02:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-12 18:30Z', 'local': '2025-12-13 00:00+05:30'},
#    'to': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 16,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 42,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T04:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-12 20:30Z', 'local': '2025-12-13 02:00+05:30'},
#    'to': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 23,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 28,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T06:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-12 22:30Z', 'local': '2025-12-13 04:00+05:30'},
#    'to': {'utc': '2025-12-13 00:30Z', 'local': '2025-12-13 06:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 54,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 15,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T08:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-13 00:30Z', 'local': '2025-12-13 06:00+05:30'},
#    'to': {'utc': '2025-12-13 02:30Z', 'local': '2025-12-13 08:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 70,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 18,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T10:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-13 02:30Z', 'local': '2025-12-13 08:00+05:30'},
#    'to': {'utc': '2025-12-13 04:30Z', 'local': '2025-12-13 10:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 59,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 59,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T12:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-13 04:30Z', 'local': '2025-12-13 10:00+05:30'},
#    'to': {'utc': '2025-12-13 06:30Z', 'local': '2025-12-13 12:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 69,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 68,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T14:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-13 06:30Z', 'local': '2025-12-13 12:00+05:30'},
#    'to': {'utc': '2025-12-13 08:30Z', 'local': '2025-12-13 14:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 61,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 59,
#     'numQualifiedTotal': 1,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T16:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-13 08:30Z', 'local': '2025-12-13 14:00+05:30'},
#    'to': {'utc': '2025-12-13 10:30Z', 'local': '2025-12-13 16:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 63,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 66,
#     'numQualifiedTotal': 1,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T18:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-13 10:30Z', 'local': '2025-12-13 16:00+05:30'},
#    'to': {'utc': '2025-12-13 12:30Z', 'local': '2025-12-13 18:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 60,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 71,
#     'numQualifiedTotal': 1,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T20:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-13 12:30Z', 'local': '2025-12-13 18:00+05:30'},
#    'to': {'utc': '2025-12-13 14:30Z', 'local': '2025-12-13 20:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 60,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 57,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-13T22:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-13 14:30Z', 'local': '2025-12-13 20:00+05:30'},
#    'to': {'utc': '2025-12-13 16:30Z', 'local': '2025-12-13 22:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 48,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 57,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0}}},
#  {'requested_ts': '2025-12-14T00:00',
#   'data': {'airportIcao': 'VIDP',
#    'from': {'utc': '2025-12-13 16:30Z', 'local': '2025-12-13 22:00+05:30'},
#    'to': {'utc': '2025-12-13 18:30Z', 'local': '2025-12-14 00:00+05:30'},
#    'departuresDelayInformation': {'numTotal': 29,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0},
#    'arrivalsDelayInformation': {'numTotal': 72,
#     'numQualifiedTotal': 0,
#     'numCancelled': 0}}}]

# %%
from db_connection import get_connection

conn = get_connection()

# %%
import sqlite3

# assuming you already have DB_CONN
cursor = conn.cursor()

cursor.execute("""
    SELECT DISTINCT aircraft_registration
    FROM flights
    WHERE aircraft_registration IS NOT NULL
""")

# fetch results and convert to Python set
aircraft_reg_set = {row[0] for row in cursor.fetchall()}

print(aircraft_reg_set)
print(f"Total distinct aircraft: {len(aircraft_reg_set)}")
# Out:
# {'EW-456PA', 'G-STBD', 'N796JB', 'A6-EVI', 'N131NN', '9V-SCE', 'VT-ANA', '9V-SJF', 'N341NB', 'TF-ISP', 'N680VM', 'VT-SLP', 'G-YMMT', 'G-EUUC', '9H-NEE', 'VH-EBO', 'N277SY', 'EI-EAV', 'B-58505', 'N8714Q', 'N204JQ', 'N508SY', 'G-XWBE', 'VT-ISA', 'G-XWBR', 'N626NK', '9V-SKM', 'N246SY', 'G-XWBK', 'N507SY', 'JY-BAF', 'EC-LUX', 'D-AENI', 'N542LA', 'N396DN', 'N603JB', 'N899DN', 'EI-KGG', 'B-7367', 'VH-OQB', 'N333NB', 'N111ZM', '9K-CBB', 'N1200K', 'N173DZ', 'N113AN', 'N860NW', '9V-SHR', 'B-LJF', 'N657UA', 'N577DN', 'G-EUYW', 'OE-IVL', 'VT-ILP', 'VT-IQK', 'A6-EIV', 'LN-RGM', 'G-STBB', 'N4064J', 'N989SF', 'A6-EQN', 'G-TTNY', 'D-ANRJ', 'G-VLDY', 'N205HA', 'A6-ENP', 'N658QX', 'XA-ADD', 'F-GKXL', 'N535AS', 'F-GSPZ', 'N974AN', 'N8508W', 'B-LJL', 'B-1566', 'VT-HKG', 'VT-ISL', 'TC-MNV', 'N610CZ', 'XA-VRR', 'G-DBCK', 'G-VNYL', 'N997AA', 'YI-ASW', 'A6-EUP', 'N998JE', 'N505DZ', 'B-KQN', 'VT-TNI', 'VT-ILS', 'N313PQ', 'N952AK', 'C-GKQO', 'XA-VAY', 'HZ-AR24', 'D-AILW', 'A6-FEB', 'VT-NAC', 'XU-729', 'N253UP', 'N782AN', 'N652JB', 'F-GZCK', '9V-SKS', 'VH-EBG', 'A6-EGS', 'N2169J', 'N407DX', '9H-HFA', 'B-32C9', 'G-VIIN', 'N569AS', 'N305NX', 'SU-GEV', 'N4048J', 'A6-FMJ', 'A6-EGV', 'YL-CSH', 'VT-ILI', 'A6-FKI', 'OO-TCV', 'C-FIBA', 'N803AL', 'A6-BMA', 'F-HBLI', 'N536JB', 'N538DN', '9V-SFM', 'F-HRBA', 'N829AN', 'SU-GEJ', 'HL8361', 'N8525S', 'N682NK', 'A6-EEE', 'VT-ISX', 'G-VIIG', 'G-EUPO', '9V-OJA', 'G-ZBJB', 'CS-TCF', 'JA879J', 'G-TTOE', 'N301PQ', 'VT-IYD', 'A6-EEQ', 'N104NN', 'N361DN', 'N487WN', 'OE-LXD', '9V-NCE', 'ZK-OKQ', 'B-LRA', 'N8550Q', 'VT-TNN', '9V-OFI', '9V-DHE', 'XA-VAE', 'N563JB', 'N279JB', 'N29978', 'G-EUUU', 'A6-EII', 'N128HQ', 'G-EUUP', 'N501SY', 'G-EUPZ', '9V-SCN', 'N651GT', 'N301NB', 'HL8212', 'D-ABYO', 'N428YX', 'F-HBXB', 'N375NC', 'N4080J', 'N370NB', 'G-EUYM', 'N418YX', 'F-GZNE', 'A6-EPT', 'N839MH', 'A6-EUT', 'N21108', 'G-EUYT', 'C-FRQM', 'VT-CIN', 'F-GUGQ', 'G-EZUI', 'G-TTNS', 'N39415', 'N45956', 'G-EIDY', 'N986JB', 'N109NN', 'LX-LQC', 'N301DV', 'A6-EPC', 'VT-IMU', 'N557XJ', 'VT-ANY', 'VT-ISQ', 'N26902', 'VT-IMH', 'N7885A', 'VT-PPU', 'N564AS', 'B-LQH', '9M-RAC', 'VT-SQD', 'VT-ANV', '9V-SHK', 'N17322', 'A4O-MG', 'VT-ANW', 'VT-PPH', 'CN-RGZ', '9V-TRW', 'OO-SSO', 'B-32DM', 'F-GZNO', 'N37516', 'EC-MAI', 'HB-JPD', 'B-LRI', 'N69888', 'VT-PPI', '9H-CXA', 'VT-ISM', 'N937AK', 'D-AIXP', 'N941AK', 'N968JT', 'N551NW', 'G-EUUK', 'N8579Z', 'A6-ECM', 'N346FR', 'HZ-AK37', 'ET-ATR', 'A6-FMM', 'JA879A', 'A9C-ND', 'N417DX', 'B-1493', 'JA805A', 'N913JB', 'F-GSQV', 'N9013A', 'F-GKXQ', 'F-HEPH', 'G-EUPY', 'VT-TSQ', 'HL8517', 'XA-VCC', 'PK-LUW', 'N658UA', 'G-DBCG', '9V-TNF', '9V-SMP', 'N326SJ', 'EI-LRG', 'N995JL', 'N674UA', 'VT-SLA', 'N507DZ', 'OE-IMD', 'C-FSJJ', '9V-MGK', 'G-RAES', 'A6-EGH', 'N2142J', 'VT-IIQ', 'N789SK', 'VT-BDA', 'F-HBLK', 'VT-SGG', 'F-HTYQ', 'VT-ILF', 'TC-JTI', 'N705JB', 'A6-EVA', 'ZK-OKM', 'VT-JRH', 'N430SY', 'G-XLEJ', 'N27292', 'VT-EXH', 'EC-OCS', 'N846NN', '9V-SFK', 'A7-AND', 'N8803L', '7T-VKC', 'C-GVWA', 'A6-FEE', 'N882BL', 'N2084J', 'F-HBLL', 'A6-FGJ', 'N210JQ', 'N181GJ', 'VT-ILE', 'N753QS', 'N654DL', 'N239WN', '9M-AHZ', 'G-EZUN', '9V-JSK', 'F-HPNM', 'VT-SYZ', 'N205JQ', 'G-EUUG', 'VT-IFZ', 'F-HRBG', 'DQ-FAI', 'N238JQ', 'G-VIIC', 'N247JL', 'F-GZCG', 'B-2077', 'G-EUYH', '9V-MBJ', 'JA827J', 'N3142J', 'A4O-BAB', 'N550DN', 'A7-BAC', 'A6-FEW', 'N659DL', 'VT-IMB', 'PK-AZP', '9V-SCW', 'G-VNVR', 'YL-LDD', 'N3215J', 'N589JB', 'A6-EGI', 'N910DU', 'TF-AEW', 'N544DN', 'A6-EVG', 'VT-IAQ', 'G-VIID', 'N393DA', 'N722AN', 'VT-TNF', 'N8570W', 'VT-IIR', 'VT-IZV', 'HK-5365', 'PH-AXB', 'F-GKXI', 'N466CA', 'N962AV', 'G-VCRU', '9V-SCT', 'A6-ENR', 'F-HRBF', 'VT-CIM', 'JY-AZC', 'N394DA', 'D-AIEN', 'VT-ILV', 'N334DN', 'N378HA', 'A6-EEW', 'N407AN', 'G-EUUA', 'N4073J', 'VT-EXO', 'N6879R', 'N713TW', 'N702GT', 'N109JS', 'N2044J', 'N292WN', 'N8638A', 'N203JQ', 'HB-JHE', '7T-VCD', '9K-AOC', 'A6-EWB', 'G-VGEM', 'N930XJ', 'G-STBH', 'G-VSRB', 'A6-EOL', 'F-GSPQ', 'EI-LRE', 'A6-EUG', 'N624QX', 'VT-NAA', 'N518DQ', 'SP-LVP', 'N585JB', 'N827AN', 'VT-EXE', 'N438AN', 'N565NC' ...
# Total distinct aircraft: 2504
